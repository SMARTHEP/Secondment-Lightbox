# %%
import numpy as np
import pandas as pd
import datetime
from matplotlib import pyplot as plt
import yfinance as yf

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import tensorflow as tf
import tensorflow_probability as tfp

# %%
# name = 'PL=F' #platinum
# name = 'GC=F' #gold
# name = 'SI=F' #silver
# name = 'HG=F' #copper
# name = 'PA=F' #paladium
# name = 'CL=F' #crude oil
# name = 'BZ=F' #brent crude oil
name = 'NG=F' #natural gas

train_end_date = '2023-07-01'

name_ohlc_df = yf.download(name, start='2010-01-01', end=train_end_date)
name_ohlc_df = name_ohlc_df.reset_index()

data = {'date': name_ohlc_df.Date, 'close': name_ohlc_df.Close}
df = pd.DataFrame(data)
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#         date   close
# 0 2010-01-04  4.6225
# 1 2010-01-05  4.6900
# 2 2010-01-06  4.7200
# 3 2010-01-07  4.6275
# 4 2010-01-08  4.6375

# %%
plt.figure(figsize=(8, 4))
plt.plot(df['date'], df['close'], linestyle='-', color='b')
plt.xlabel('Date')
plt.ylabel('Temperature')
plt.title(name+' Price')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# x1 = np.array(df.iloc[:,1]+np.random.randn(df.shape[0])).astype(np.float32).reshape(-1,1)
train_size = int(0.75 * len(df))

# x1 = np.array(df.iloc[:train_size,1]).astype(np.float32).reshape(-1,1)
sequence_length = 10
train_input = np.lib.stride_tricks.sliding_window_view(df.iloc[:train_size,1].values, sequence_length)
val_input = np.lib.stride_tricks.sliding_window_view(df.iloc[train_size:-1,1].values, sequence_length)

y1 = np.array(df.iloc[sequence_length:train_size+1,1]).T.astype(np.float32).reshape(-1,1)
y2 = np.array(df.iloc[sequence_length+train_size:,1]).T.astype(np.float32).reshape(-1,1)

tfd = tfp.distributions

# %%
# print(train_input[:2])
# print()
# print(y1[:2])
# print(train_input.shape,y1.shape)

print(val_input[:2])
print()
print(y2[:2])
print(val_input.shape,y2.shape)
# Out:
# [[74.14250183 78.67500305 77.17500305 73.51750183 68.31999969 65.51249695
#   66.91249847 63.15000153 67.51750183 69.10749817]
#  [78.67500305 77.17500305 73.51750183 68.31999969 65.51249695 66.91249847
#   63.15000153 67.51750183 69.10749817 66.47250366]]
#
# [[66.4725]
#  [71.1275]]
# (839, 10) (839, 1)

# %%
# Specify the surrogate posterior over `keras.layers.Dense` `kernel` and `bias`.
def posterior_mean_field(kernel_size, bias_size=0, dtype=None):
  n = kernel_size + bias_size
  c = np.log(np.expm1(1.))
  return tf.keras.Sequential([
      tfp.layers.VariableLayer(2 * n, dtype=dtype),
      tfp.layers.DistributionLambda(lambda t: tfd.Independent(
          tfd.Normal(loc=t[..., :n],
                     scale=1e-5 + tf.nn.softplus(c + t[..., n:])),
          reinterpreted_batch_ndims=1)),
  ])

# Specify the prior over `keras.layers.Dense` `kernel` and `bias`.
def prior_trainable(kernel_size, bias_size=0, dtype=None):
  n = kernel_size + bias_size
  return tf.keras.Sequential([
      tfp.layers.VariableLayer(n, dtype=dtype),
      tfp.layers.DistributionLambda(lambda t: tfd.Independent(
          tfd.Normal(loc=t, scale=1),
          reinterpreted_batch_ndims=1)),
  ])

# %%
model = tf.keras.Sequential([
  tf.keras.layers.Dense(32,activation='relu'),
  tfp.layers.DenseVariational(1 + 1, posterior_mean_field, prior_trainable, kl_weight=1/train_input.shape[0]),
  tfp.layers.DistributionLambda(
      # lambda t: tfd.Normal(loc=t[..., :1],scale=1e-3 + tf.math.softplus(0.001 * t[...,1:]))),
      lambda t: tfd.StudentT(df=4,loc=t[..., :1],scale=1e-3 + 0.001*tf.math.softplus(t[...,1:]))),
      # lambda t: tfd.TwoPieceStudentT(df=5,loc=t[..., :1],scale=1e-3 + 0.1*tf.math.softplus(t[...,1:2]),skewness=0.1 + 0.1*tf.math.softplus(t[...,2:]))),

])

# %%
negloglik = lambda y, rv_y: -rv_y.log_prob(y)

# Do inference.
model.compile(optimizer=tf.optimizers.legacy.Adam(learning_rate=0.01), loss=negloglik)
model.fit(train_input, y1, epochs=1500, verbose=1);
# Out:
# Epoch 1/1500
# 80/80 [==============================] - 1s 674us/step - loss: 29.1817
# Epoch 2/1500
# 80/80 [==============================] - 0s 560us/step - loss: 25.8959
# Epoch 3/1500
# 80/80 [==============================] - 0s 533us/step - loss: 25.6607
# Epoch 4/1500
# 80/80 [==============================] - 0s 549us/step - loss: 21.2758
# Epoch 5/1500
# 80/80 [==============================] - 0s 525us/step - loss: 21.7492
# Epoch 6/1500
# 80/80 [==============================] - 0s 552us/step - loss: 19.9664
# Epoch 7/1500
# 80/80 [==============================] - 0s 1ms/step - loss: 20.1746
# Epoch 8/1500
# 80/80 [==============================] - 0s 487us/step - loss: 18.6527
# Epoch 9/1500
# 80/80 [==============================] - 0s 548us/step - loss: 19.0634
# Epoch 10/1500
# 80/80 [==============================] - 0s 573us/step - loss: 18.0546
# Epoch 11/1500
# 80/80 [==============================] - 0s 556us/step - loss: 16.1816
# Epoch 12/1500
# 80/80 [==============================] - 0s 1ms/step - loss: 16.7825
# Epoch 13/1500
# 80/80 [==============================] - 0s 527us/step - loss: 15.4284
# Epoch 14/1500
# 80/80 [==============================] - 0s 529us/step - loss: 13.8303
# Epoch 15/1500
# 80/80 [==============================] - 0s 605us/step - loss: 14.0701
# Epoch 16/1500
# 80/80 [==============================] - 0s 514us/step - loss: 11.9570
# Epoch 17/1500
# 80/80 [==============================] - 0s 485us/step - loss: 11.4331
# Epoch 18/1500
# 80/80 [==============================] - 0s 934us/step - loss: 9.5657
# Epoch 19/1500
# 80/80 [==============================] - 0s 506us/step - loss: 6.5963
# Epoch 20/1500
# 80/80 [==============================] - 0s 492us/step - loss: 5.3933
# Epoch 21/1500
# 80/80 [==============================] - 0s 488us/step - loss: 4.7493
# Epoch 22/1500
# 80/80 [==============================] - 0s 486us/step - loss: 4.1452
# Epoch 23/1500
# 80/80 [==============================] - 0s 483us/step - loss: 3.0490
# Epoch 24/1500
# 80/80 [==============================] - 0s 1ms/step - loss: 2.9596
# Epoch 25/1500
# 80/80 [==============================] - 0s 546us/step - loss: 1.9767
# Epoch 26/1500
# 80/80 [==============================] - 0s 536us/step - loss: 1.8545
# Epoch 27/1500
# 80/80 [==============================] - 0s 498us/step - loss: 1.5888
# Epoch 28/1500
# 80/80 [==============================] - 0s 491us/step - loss: 1.3803
# Epoch 29/1500
# 80/80 [==============================] - 0s 1ms/step - loss: 1.2180
# Epoch 30/1500
# 80/80 [==============================] - 0s 509us/step - loss: 1.0684
# Epoch 31/1500
# 80/80 [==============================] - 0s 503us/step - loss: 0.9541
# Epoch 32/1500
# 80/80 [==============================] - 0s 487us/step - loss: 0.8075
# Epoch 33/1500
# 80/80 [==============================] - 0s 482us/step - loss: 1.0181
# Epoch 34/1500
# 80/80 [==============================] - 0s 819us/step - loss: 0.8635
# Epoch 35/1500
# 80/80 [==============================] - 0s 1ms/step - loss: 0.6854
# Epoch 36/1500
# 80/80 [==============================] - 0s 500us/step - loss: 0.7440
# Epoch 37/1500
# 80/80 [==============================] - 0s 493us/step - loss: 0.6167
# Epoch 38/1500
# 80/80 [==============================] - 0s 512us/step - loss: 0.6423
# Epoch 39/1500
# 80/80 [==============================] - 0s 509us/step - loss: 0.5518
# Epoch 40/1500
# 80/80 [==============================] - 0s 553us/step - loss: 0.5883
# Epoch 41/1500
# 80/80 [==============================] - 0s 1ms/step - loss: 0.4468
# Epoch 42/1500
# 80/80 [==============================] - 0s 588us/step - loss: 0.5179
# Epoch 43/1500
# 80/80 [==============================] - 0s 484us/step - loss: 0.4551
# Epoch 44/1500
# 80/80 [==============================] - 0s 518us/step - loss: 0.4271
# Epoch 45/1500
# 80/80 [==============================] - 0s 575us/step - loss: 0.4259
# Epoch 46/1500
# 80/80 [==============================] - 0s 993us/step - loss: 0.4283
# Epoch 47/1500
# 80/80 [==============================] - 0s 520us/step - loss: 0.4905
# Epoch 48/1500
# 80/80 [==============================] - 0s 525us/step - loss: 0.3303
# Epoch 49/1500
# 80/80 [==============================] - 0s 580us/step - loss: 0.3440
# Epoch 50/1500
# 80/80 [==============================] - 0s 482us/step - loss: 0.3228
# Epoch 51/1500
# 80/80 [==============================] - 0s 986us/step - loss: 0.3608
# Epoch 52/1500
# 80/80 [==============================] - 0s 571us/step - loss: 0.3499
# Epoch 53/1500
# 80/80 [==============================] - 0s 563us/step - loss: 0.3194
# Epoch 54/1500
# 80/80 [==============================] - 0s 555us/step - loss: 0.2866
# Epoch 55/1500
# 80/80 [==============================] - 0s 507us/step - loss: 0.2064
# Epoch 56/1500
# 80/80 [==============================] - 0s 513us/step - loss: 0.2168
# Epoch 57/1500
# 80/80 [==============================] - 0s 1ms/step - loss: 0.2072
# Epoch 58/1500
# 80/80 [==============================] - 0s 501us/step - loss: 0.1895
# Epoch 59/1500
# 80/80 [==============================] - 0s 489us/step - loss: 0.2216
# Epoch 60/1500
# 80/80 [==============================] - 0s 492us/step - loss: 0.1858
# Epoch 61/1500
# 80/80 [==============================] - 0s 492us/step - loss: 0.2169
# Epoch 62/1500
# 80/80 [==============================] - 0s 487us/step - loss: 0.2008
# Epoch 63/1500
# 80/80 [==============================] - 0s 968us/step - loss: 0.2261
# Epoch 64/1500
# 80/80 [==============================] - 0s 487us/step - loss: 0.2179
# Epoch 65/1500
# 80/80 [==============================] - 0s 463us/step - loss: 0.1870
# Epoch 66/1500
# 80/80 [==============================] - 0s 481us/step - loss: 0.1667
# Epoch 67/1500
# 80/80 [==============================] - 0s 483us/step - loss: 0.1279
# Epoch 68/1500
# 80/80 [==============================] - 0s 933us/step - loss: 0.1210
# Epoch 69/1500
# 80/80 [==============================] - 0s 751us/step - loss: 0.1335
# Epoch 70/1500
# 80/80 [==============================] - 0s 468us/step - loss: 0.1073
# Epoch 71/1500
# 80/80 [==============================] - 0s 481us/step - loss: 0.0825
# Epoch 72/1500
# 80/80 [==============================] - 0s 476us/step - loss: 0.1412
# Epoch 73/1500
# 80/80 [==============================] - 0s 485us/step - loss: 0.1206
# Epoch 74/1500
# 80/80 [==============================] - 0s 1ms/step - loss: 0.2052
# Epoch 75/1500
# 80/80 [==============================] - 0s 525us/step - loss: 0.2069
# Epoch 76/1500
# 80/80 [==============================] - 0s 608us/step - loss: 0.0981
# Epoch 77/1500
# 80/80 [==============================] - 0s 494us/step - loss: 0.1956
# Epoch 78/1500
# 80/80 [==============================] - 0s 498us/step - loss: 0.1647
# Epoch 79/1500
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0771
# Epoch 80/1500
# 80/80 [==============================] - 0s 551us/step - loss: 0.1043
# Epoch 81/1500
# 80/80 [==============================] - 0s 548us/step - loss: 0.0644
# Epoch 82/1500
# 80/80 [==============================] - 0s 499us/step - loss: 0.0404
# Epoch 83/1500
# 80/80 [==============================] - 0s 503us/step - loss: 0.0508
# Epoch 84/1500
# 80/80 [==============================] - 0s 482us/step - loss: 0.0866
# Epoch 85/1500
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0494
# Epoch 86/1500
# 80/80 [==============================] - 0s 691us/step - loss: 0.0757
# Epoch 87/1500
# 80/80 [==============================] - 0s 492us/step - loss: 0.0308
# Epoch 88/1500
# 80/80 [==============================] - 0s 496us/step - loss: 0.0596
# Epoch 89/1500
# 80/80 [==============================] - 0s 515us/step - loss: 0.0613
# Epoch 90/1500
# 80/80 [==============================] - 0s 494us/step - loss: 0.0716
# Epoch 91/1500
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0806
# Epoch 92/1500
# 80/80 [==============================] - 0s 570us/step - loss: 0.0029
# Epoch 93/1500
# 80/80 [==============================] - 0s 521us/step - loss: 0.0114
# Epoch 94/1500
# 80/80 [==============================] - 0s 502us/step - loss: 0.0058
# Epoch 95/1500
# 80/80 [==============================] - 0s 497us/step - loss: 0.0346
# Epoch 96/1500
# 80/80 [==============================] - 0s 795us/step - loss: 0.0023
# Epoch 97/1500
# 80/80 [==============================] - 0s 766us/step - loss: 0.0140
# Epoch 98/1500
# 80/80 [==============================] - 0s 517us/step - loss: -0.0042
# Epoch 99/1500
# 80/80 [==============================] - 0s 537us/step - loss: -7.1761e-04
# Epoch 100/1500
# 80/80 [==============================] - 0s 506us/step - loss: 0.0326
# Epoch 101/1500
# 80/80 [==============================] - 0s 503us/step - loss: 2.4302e-04
# Epoch 102/1500
# 80/80 [==============================] - 0s 492us/step - loss: 0.0228
# Epoch 103/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0247
# Epoch 104/1500
# 80/80 [==============================] - 0s 499us/step - loss: 0.0277
# Epoch 105/1500
# 80/80 [==============================] - 0s 490us/step - loss: 0.0371
# Epoch 106/1500
# 80/80 [==============================] - 0s 496us/step - loss: 0.0533
# Epoch 107/1500
# 80/80 [==============================] - 0s 505us/step - loss: -0.0136
# Epoch 108/1500
# 80/80 [==============================] - 0s 831us/step - loss: -0.0164
# Epoch 109/1500
# 80/80 [==============================] - 0s 692us/step - loss: -0.0210
# Epoch 110/1500
# 80/80 [==============================] - 0s 527us/step - loss: 0.0300
# Epoch 111/1500
# 80/80 [==============================] - 0s 593us/step - loss: -0.0331
# Epoch 112/1500
# 80/80 [==============================] - 0s 563us/step - loss: -0.0128
# Epoch 113/1500
# 80/80 [==============================] - 0s 557us/step - loss: 0.0524
# Epoch 114/1500
# 80/80 [==============================] - 0s 914us/step - loss: 0.0228
# Epoch 115/1500
# 80/80 [==============================] - 0s 774us/step - loss: 0.0253
# Epoch 116/1500
# 80/80 [==============================] - 0s 583us/step - loss: 0.0331
# Epoch 117/1500
# 80/80 [==============================] - 0s 613us/step - loss: 0.0052
# Epoch 118/1500
# 80/80 [==============================] - 0s 615us/step - loss: -0.0162
# Epoch 119/1500
# 80/80 [==============================] - 0s 634us/step - loss: 3.6048e-04
# Epoch 120/1500
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0097
# Epoch 121/1500
# 80/80 [==============================] - 0s 690us/step - loss: 0.1218
# Epoch 122/1500
# 80/80 [==============================] - 0s 713us/step - loss: -0.0039
# Epoch 123/1500
# 80/80 [==============================] - 0s 577us/step - loss: 0.0154
# Epoch 124/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0229
# Epoch 125/1500
# 80/80 [==============================] - 0s 793us/step - loss: 0.0077
# Epoch 126/1500
# 80/80 [==============================] - 0s 605us/step - loss: -0.0011
# Epoch 127/1500
# 80/80 [==============================] - 0s 529us/step - loss: -0.0447
# Epoch 128/1500
# 80/80 [==============================] - 0s 542us/step - loss: -0.0305
# Epoch 129/1500
# 80/80 [==============================] - 0s 975us/step - loss: -0.0241
# Epoch 130/1500
# 80/80 [==============================] - 0s 649us/step - loss: -0.0284
# Epoch 131/1500
# 80/80 [==============================] - 0s 562us/step - loss: -0.0329
# Epoch 132/1500
# 80/80 [==============================] - 0s 715us/step - loss: 0.0235
# Epoch 133/1500
# 80/80 [==============================] - 0s 557us/step - loss: 0.0274
# Epoch 134/1500
# 80/80 [==============================] - 0s 542us/step - loss: 0.0184
# Epoch 135/1500
# 80/80 [==============================] - 0s 917us/step - loss: -0.0015
# Epoch 136/1500
# 80/80 [==============================] - 0s 747us/step - loss: 0.0029
# Epoch 137/1500
# 80/80 [==============================] - 0s 552us/step - loss: -0.0362
# Epoch 138/1500
# 80/80 [==============================] - 0s 580us/step - loss: 0.0078
# Epoch 139/1500
# 80/80 [==============================] - 0s 604us/step - loss: -0.0076
# Epoch 140/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0497
# Epoch 141/1500
# 80/80 [==============================] - 0s 702us/step - loss: -0.0280
# Epoch 142/1500
# 80/80 [==============================] - 0s 534us/step - loss: -0.0224
# Epoch 143/1500
# 80/80 [==============================] - 0s 524us/step - loss: 0.0025
# Epoch 144/1500
# 80/80 [==============================] - 0s 564us/step - loss: -0.0396
# Epoch 145/1500
# 80/80 [==============================] - 0s 926us/step - loss: -0.0170
# Epoch 146/1500
# 80/80 [==============================] - 0s 661us/step - loss: -0.0555
# Epoch 147/1500
# 80/80 [==============================] - 0s 550us/step - loss: -0.0020
# Epoch 148/1500
# 80/80 [==============================] - 0s 547us/step - loss: 0.0056
# Epoch 149/1500
# 80/80 [==============================] - 0s 559us/step - loss: -0.0321
# Epoch 150/1500
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0585
# Epoch 151/1500
# 80/80 [==============================] - 0s 844us/step - loss: -0.0494
# Epoch 152/1500
# 80/80 [==============================] - 0s 599us/step - loss: 0.0128
# Epoch 153/1500
# 80/80 [==============================] - 0s 657us/step - loss: -0.0200
# Epoch 154/1500
# 80/80 [==============================] - 0s 668us/step - loss: 7.8197e-04
# Epoch 155/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0131
# Epoch 156/1500
# 80/80 [==============================] - 0s 896us/step - loss: -0.0061
# Epoch 157/1500
# 80/80 [==============================] - 0s 565us/step - loss: -0.0324
# Epoch 158/1500
# 80/80 [==============================] - 0s 565us/step - loss: -0.0260
# Epoch 159/1500
# 80/80 [==============================] - 0s 564us/step - loss: -0.0100
# Epoch 160/1500
# 80/80 [==============================] - 0s 552us/step - loss: -0.0512
# Epoch 161/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0497
# Epoch 162/1500
# 80/80 [==============================] - 0s 543us/step - loss: -0.0496
# Epoch 163/1500
# 80/80 [==============================] - 0s 656us/step - loss: 0.0239
# Epoch 164/1500
# 80/80 [==============================] - 0s 532us/step - loss: -0.0240
# Epoch 165/1500
# 80/80 [==============================] - 0s 561us/step - loss: -0.0536
# Epoch 166/1500
# 80/80 [==============================] - 0s 996us/step - loss: -0.0138
# Epoch 167/1500
# 80/80 [==============================] - 0s 597us/step - loss: 2.8805e-04
# Epoch 168/1500
# 80/80 [==============================] - 0s 518us/step - loss: 0.0963
# Epoch 169/1500
# 80/80 [==============================] - 0s 618us/step - loss: -0.0208
# Epoch 170/1500
# 80/80 [==============================] - 0s 516us/step - loss: -0.0331
# Epoch 171/1500
# 80/80 [==============================] - 0s 516us/step - loss: -0.0108
# Epoch 172/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0382
# Epoch 173/1500
# 80/80 [==============================] - 0s 680us/step - loss: -0.0354
# Epoch 174/1500
# 80/80 [==============================] - 0s 607us/step - loss: 0.0058
# Epoch 175/1500
# 80/80 [==============================] - 0s 575us/step - loss: 0.0204
# Epoch 176/1500
# 80/80 [==============================] - 0s 738us/step - loss: -0.0012
# Epoch 177/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0195
# Epoch 178/1500
# 80/80 [==============================] - 0s 543us/step - loss: -0.0464
# Epoch 179/1500
# 80/80 [==============================] - 0s 521us/step - loss: -0.0296
# Epoch 180/1500
# 80/80 [==============================] - 0s 554us/step - loss: -0.0451
# Epoch 181/1500
# 80/80 [==============================] - 0s 524us/step - loss: 0.0251
# Epoch 182/1500
# 80/80 [==============================] - 0s 493us/step - loss: 0.0133
# Epoch 183/1500
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0163
# Epoch 184/1500
# 80/80 [==============================] - 0s 606us/step - loss: -0.0260
# Epoch 185/1500
# 80/80 [==============================] - 0s 502us/step - loss: -0.0098
# Epoch 186/1500
# 80/80 [==============================] - 0s 512us/step - loss: -0.0242
# Epoch 187/1500
# 80/80 [==============================] - 0s 500us/step - loss: -0.0120
# Epoch 188/1500
# 80/80 [==============================] - 0s 977us/step - loss: -0.0479
# Epoch 189/1500
# 80/80 [==============================] - 0s 632us/step - loss: -0.0374
# Epoch 190/1500
# 80/80 [==============================] - 0s 519us/step - loss: 0.0264
# Epoch 191/1500
# 80/80 [==============================] - 0s 498us/step - loss: -0.0203
# Epoch 192/1500
# 80/80 [==============================] - 0s 514us/step - loss: 0.0027
# Epoch 193/1500
# 80/80 [==============================] - 0s 633us/step - loss: 0.0516
# Epoch 194/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0470
# Epoch 195/1500
# 80/80 [==============================] - 0s 553us/step - loss: -0.0623
# Epoch 196/1500
# 80/80 [==============================] - 0s 505us/step - loss: -0.0543
# Epoch 197/1500
# 80/80 [==============================] - 0s 495us/step - loss: 0.0318
# Epoch 198/1500
# 80/80 [==============================] - 0s 498us/step - loss: -0.0196
# Epoch 199/1500
# 80/80 [==============================] - 0s 521us/step - loss: -0.0477
# Epoch 200/1500
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0382
# Epoch 201/1500
# 80/80 [==============================] - 0s 608us/step - loss: 0.0057
# Epoch 202/1500
# 80/80 [==============================] - 0s 520us/step - loss: -0.0316
# Epoch 203/1500
# 80/80 [==============================] - 0s 499us/step - loss: 0.0345
# Epoch 204/1500
# 80/80 [==============================] - 0s 515us/step - loss: -0.0199
# Epoch 205/1500
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0214
# Epoch 206/1500
# 80/80 [==============================] - 0s 523us/step - loss: -0.0091
# Epoch 207/1500
# 80/80 [==============================] - 0s 502us/step - loss: 0.0342
# Epoch 208/1500
# 80/80 [==============================] - 0s 504us/step - loss: -0.0469
# Epoch 209/1500
# 80/80 [==============================] - 0s 586us/step - loss: -0.0632
# Epoch 210/1500
# 80/80 [==============================] - 0s 505us/step - loss: -0.0234
# Epoch 211/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0330
# Epoch 212/1500
# 80/80 [==============================] - 0s 597us/step - loss: -0.0033
# Epoch 213/1500
# 80/80 [==============================] - 0s 546us/step - loss: -0.0594
# Epoch 214/1500
# 80/80 [==============================] - 0s 508us/step - loss: 0.0314
# Epoch 215/1500
# 80/80 [==============================] - 0s 507us/step - loss: -0.0208
# Epoch 216/1500
# 80/80 [==============================] - 0s 497us/step - loss: 0.0480
# Epoch 217/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0464
# Epoch 218/1500
# 80/80 [==============================] - 0s 523us/step - loss: -0.0520
# Epoch 219/1500
# 80/80 [==============================] - 0s 518us/step - loss: -0.0518
# Epoch 220/1500
# 80/80 [==============================] - 0s 526us/step - loss: -0.0629
# Epoch 221/1500
# 80/80 [==============================] - 0s 499us/step - loss: -0.0412
# Epoch 222/1500
# 80/80 [==============================] - 0s 497us/step - loss: -0.0210
# Epoch 223/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0168
# Epoch 224/1500
# 80/80 [==============================] - 0s 626us/step - loss: -0.0570
# Epoch 225/1500
# 80/80 [==============================] - 0s 498us/step - loss: -0.0272
# Epoch 226/1500
# 80/80 [==============================] - 0s 520us/step - loss: -0.0194
# Epoch 227/1500
# 80/80 [==============================] - 0s 513us/step - loss: 0.0289
# Epoch 228/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0315
# Epoch 229/1500
# 80/80 [==============================] - 0s 574us/step - loss: -0.0640
# Epoch 230/1500
# 80/80 [==============================] - 0s 522us/step - loss: -0.0112
# Epoch 231/1500
# 80/80 [==============================] - 0s 605us/step - loss: 0.0188
# Epoch 232/1500
# 80/80 [==============================] - 0s 520us/step - loss: -0.0543
# Epoch 233/1500
# 80/80 [==============================] - 0s 514us/step - loss: -0.0133
# Epoch 234/1500
# 80/80 [==============================] - 0s 526us/step - loss: -0.0563
# Epoch 235/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0467
# Epoch 236/1500
# 80/80 [==============================] - 0s 526us/step - loss: 0.0581
# Epoch 237/1500
# 80/80 [==============================] - 0s 503us/step - loss: -0.0243
# Epoch 238/1500
# 80/80 [==============================] - 0s 616us/step - loss: -0.0598
# Epoch 239/1500
# 80/80 [==============================] - 0s 506us/step - loss: -0.0176
# Epoch 240/1500
# 80/80 [==============================] - 0s 526us/step - loss: -0.0237
# Epoch 241/1500
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0307
# Epoch 242/1500
# 80/80 [==============================] - 0s 498us/step - loss: 0.1069
# Epoch 243/1500
# 80/80 [==============================] - 0s 504us/step - loss: -0.0163
# Epoch 244/1500
# 80/80 [==============================] - 0s 523us/step - loss: -0.0197
# Epoch 245/1500
# 80/80 [==============================] - 0s 601us/step - loss: -0.0401
# Epoch 246/1500
# 80/80 [==============================] - 0s 503us/step - loss: -0.0115
# Epoch 247/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0274
# Epoch 248/1500
# 80/80 [==============================] - 0s 539us/step - loss: -0.0505
# Epoch 249/1500
# 80/80 [==============================] - 0s 497us/step - loss: -0.0619
# Epoch 250/1500
# 80/80 [==============================] - 0s 518us/step - loss: -0.0161
# Epoch 251/1500
# 80/80 [==============================] - 0s 494us/step - loss: -0.0389
# Epoch 252/1500
# 80/80 [==============================] - 0s 594us/step - loss: -0.0394
# Epoch 253/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0541
# Epoch 254/1500
# 80/80 [==============================] - 0s 513us/step - loss: -0.0484
# Epoch 255/1500
# 80/80 [==============================] - 0s 508us/step - loss: -0.0730
# Epoch 256/1500
# 80/80 [==============================] - 0s 516us/step - loss: -0.0489
# Epoch 257/1500
# 80/80 [==============================] - 0s 508us/step - loss: -0.0084
# Epoch 258/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0268
# Epoch 259/1500
# 80/80 [==============================] - 0s 551us/step - loss: -0.0410
# Epoch 260/1500
# 80/80 [==============================] - 0s 516us/step - loss: -0.0377
# Epoch 261/1500
# 80/80 [==============================] - 0s 515us/step - loss: -0.0256
# Epoch 262/1500
# 80/80 [==============================] - 0s 502us/step - loss: 0.0305
# Epoch 263/1500
# 80/80 [==============================] - 0s 518us/step - loss: 0.0289
# Epoch 264/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0495
# Epoch 265/1500
# 80/80 [==============================] - 0s 507us/step - loss: -0.0234
# Epoch 266/1500
# 80/80 [==============================] - 0s 493us/step - loss: 0.0058
# Epoch 267/1500
# 80/80 [==============================] - 0s 526us/step - loss: -0.0086
# Epoch 268/1500
# 80/80 [==============================] - 0s 494us/step - loss: -0.0498
# Epoch 269/1500
# 80/80 [==============================] - 0s 957us/step - loss: -0.0335
# Epoch 270/1500
# 80/80 [==============================] - 0s 817us/step - loss: -0.0199
# Epoch 271/1500
# 80/80 [==============================] - 0s 516us/step - loss: -0.0710
# Epoch 272/1500
# 80/80 [==============================] - 0s 523us/step - loss: -0.0330
# Epoch 273/1500
# 80/80 [==============================] - 0s 509us/step - loss: 0.0801
# Epoch 274/1500
# 80/80 [==============================] - 0s 518us/step - loss: 0.0501
# Epoch 275/1500
# 80/80 [==============================] - 0s 1ms/step - loss: 3.4157e-04
# Epoch 276/1500
# 80/80 [==============================] - 0s 525us/step - loss: 0.0075
# Epoch 277/1500
# 80/80 [==============================] - 0s 515us/step - loss: 0.0295
# Epoch 278/1500
# 80/80 [==============================] - 0s 517us/step - loss: -0.0068
# Epoch 279/1500
# 80/80 [==============================] - 0s 508us/step - loss: -0.0704
# Epoch 280/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0464
# Epoch 281/1500
# 80/80 [==============================] - 0s 631us/step - loss: -0.0570
# Epoch 282/1500
# 80/80 [==============================] - 0s 518us/step - loss: -0.0435
# Epoch 283/1500
# 80/80 [==============================] - 0s 507us/step - loss: -0.0748
# Epoch 284/1500
# 80/80 [==============================] - 0s 514us/step - loss: -0.0369
# Epoch 285/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0372
# Epoch 286/1500
# 80/80 [==============================] - 0s 519us/step - loss: -0.0651
# Epoch 287/1500
# 80/80 [==============================] - 0s 576us/step - loss: -0.0317
# Epoch 288/1500
# 80/80 [==============================] - 0s 545us/step - loss: -0.0564
# Epoch 289/1500
# 80/80 [==============================] - 0s 497us/step - loss: -0.0415
# Epoch 290/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0113
# Epoch 291/1500
# 80/80 [==============================] - 0s 530us/step - loss: -0.0695
# Epoch 292/1500
# 80/80 [==============================] - 0s 498us/step - loss: -0.0476
# Epoch 293/1500
# 80/80 [==============================] - 0s 590us/step - loss: -0.0487
# Epoch 294/1500
# 80/80 [==============================] - 0s 526us/step - loss: -0.0717
# Epoch 295/1500
# 80/80 [==============================] - 0s 516us/step - loss: 0.0621
# Epoch 296/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0656
# Epoch 297/1500
# 80/80 [==============================] - 0s 520us/step - loss: -0.0712
# Epoch 298/1500
# 80/80 [==============================] - 0s 497us/step - loss: -0.0208
# Epoch 299/1500
# 80/80 [==============================] - 0s 649us/step - loss: -0.0285
# Epoch 300/1500
# 80/80 [==============================] - 0s 510us/step - loss: -0.0303
# Epoch 301/1500
# 80/80 [==============================] - 0s 502us/step - loss: -0.0125
# Epoch 302/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0625
# Epoch 303/1500
# 80/80 [==============================] - 0s 521us/step - loss: -0.0499
# Epoch 304/1500
# 80/80 [==============================] - 0s 506us/step - loss: -0.0157
# Epoch 305/1500
# 80/80 [==============================] - 0s 619us/step - loss: -0.0337
# Epoch 306/1500
# 80/80 [==============================] - 0s 512us/step - loss: -0.0398
# Epoch 307/1500
# 80/80 [==============================] - 0s 514us/step - loss: -0.0431
# Epoch 308/1500
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0062
# Epoch 309/1500
# 80/80 [==============================] - 0s 506us/step - loss: 0.0228
# Epoch 310/1500
# 80/80 [==============================] - 0s 517us/step - loss: 0.0144
# Epoch 311/1500
# 80/80 [==============================] - 0s 615us/step - loss: -0.0461
# Epoch 312/1500
# 80/80 [==============================] - 0s 520us/step - loss: -0.0234
# Epoch 313/1500
# 80/80 [==============================] - 0s 497us/step - loss: -0.0697
# Epoch 314/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0374
# Epoch 315/1500
# 80/80 [==============================] - 0s 515us/step - loss: -0.0107
# Epoch 316/1500
# 80/80 [==============================] - 0s 511us/step - loss: -0.0587
# Epoch 317/1500
# 80/80 [==============================] - 0s 607us/step - loss: -0.0606
# Epoch 318/1500
# 80/80 [==============================] - 0s 511us/step - loss: -0.0515
# Epoch 319/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0432
# Epoch 320/1500
# 80/80 [==============================] - 0s 515us/step - loss: 0.0053
# Epoch 321/1500
# 80/80 [==============================] - 0s 503us/step - loss: -0.0800
# Epoch 322/1500
# 80/80 [==============================] - 0s 512us/step - loss: -0.0515
# Epoch 323/1500
# 80/80 [==============================] - 0s 615us/step - loss: -0.0421
# Epoch 324/1500
# 80/80 [==============================] - 0s 523us/step - loss: -0.0316
# Epoch 325/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0384
# Epoch 326/1500
# 80/80 [==============================] - 0s 507us/step - loss: -5.5624e-04
# Epoch 327/1500
# 80/80 [==============================] - 0s 497us/step - loss: -0.0019
# Epoch 328/1500
# 80/80 [==============================] - 0s 526us/step - loss: -0.0613
# Epoch 329/1500
# 80/80 [==============================] - 0s 619us/step - loss: -0.0426
# Epoch 330/1500
# 80/80 [==============================] - 0s 499us/step - loss: -0.0480
# Epoch 331/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0423
# Epoch 332/1500
# 80/80 [==============================] - 0s 536us/step - loss: -0.0630
# Epoch 333/1500
# 80/80 [==============================] - 0s 516us/step - loss: 4.1311e-05
# Epoch 334/1500
# 80/80 [==============================] - 0s 523us/step - loss: -0.0352
# Epoch 335/1500
# 80/80 [==============================] - 0s 590us/step - loss: -0.0087
# Epoch 336/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0011
# Epoch 337/1500
# 80/80 [==============================] - 0s 527us/step - loss: -0.0367
# Epoch 338/1500
# 80/80 [==============================] - 0s 495us/step - loss: -0.0445
# Epoch 339/1500
# 80/80 [==============================] - 0s 521us/step - loss: -0.0328
# Epoch 340/1500
# 80/80 [==============================] - 0s 592us/step - loss: -0.0216
# Epoch 341/1500
# 80/80 [==============================] - 0s 525us/step - loss: -0.0594
# Epoch 342/1500
# 80/80 [==============================] - 0s 988us/step - loss: -0.0274
# Epoch 343/1500
# 80/80 [==============================] - 0s 520us/step - loss: -0.0087
# Epoch 344/1500
# 80/80 [==============================] - 0s 505us/step - loss: -0.0409
# Epoch 345/1500
# 80/80 [==============================] - 0s 557us/step - loss: -0.0569
# Epoch 346/1500
# 80/80 [==============================] - 0s 568us/step - loss: 0.0016
# Epoch 347/1500
# 80/80 [==============================] - 0s 507us/step - loss: -0.0090
# Epoch 348/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -8.2212e-04
# Epoch 349/1500
# 80/80 [==============================] - 0s 502us/step - loss: -0.0531
# Epoch 350/1500
# 80/80 [==============================] - 0s 584us/step - loss: -0.0297
# Epoch 351/1500
# 80/80 [==============================] - 0s 507us/step - loss: -0.0268
# Epoch 352/1500
# 80/80 [==============================] - 0s 522us/step - loss: 0.0853
# Epoch 353/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0240
# Epoch 354/1500
# 80/80 [==============================] - 0s 542us/step - loss: -0.0355
# Epoch 355/1500
# 80/80 [==============================] - 0s 504us/step - loss: -0.0440
# Epoch 356/1500
# 80/80 [==============================] - 0s 592us/step - loss: -0.0080
# Epoch 357/1500
# 80/80 [==============================] - 0s 519us/step - loss: 0.0396
# Epoch 358/1500
# 80/80 [==============================] - 0s 500us/step - loss: -0.0541
# Epoch 359/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0094
# Epoch 360/1500
# 80/80 [==============================] - 0s 654us/step - loss: 0.0320
# Epoch 361/1500
# 80/80 [==============================] - 0s 491us/step - loss: -0.0611
# Epoch 362/1500
# 80/80 [==============================] - 0s 520us/step - loss: -0.0377
# Epoch 363/1500
# 80/80 [==============================] - 0s 505us/step - loss: -0.0344
# Epoch 364/1500
# 80/80 [==============================] - 0s 494us/step - loss: -0.0748
# Epoch 365/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0524
# Epoch 366/1500
# 80/80 [==============================] - 0s 532us/step - loss: 0.0023
# Epoch 367/1500
# 80/80 [==============================] - 0s 499us/step - loss: -0.0047
# Epoch 368/1500
# 80/80 [==============================] - 0s 512us/step - loss: -0.0384
# Epoch 369/1500
# 80/80 [==============================] - 0s 585us/step - loss: -0.0261
# Epoch 370/1500
# 80/80 [==============================] - 0s 555us/step - loss: -0.0507
# Epoch 371/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0490
# Epoch 372/1500
# 80/80 [==============================] - 0s 507us/step - loss: -0.0525
# Epoch 373/1500
# 80/80 [==============================] - 0s 493us/step - loss: -0.0163
# Epoch 374/1500
# 80/80 [==============================] - 0s 584us/step - loss: -0.0220
# Epoch 375/1500
# 80/80 [==============================] - 0s 559us/step - loss: -0.0264
# Epoch 376/1500
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0129
# Epoch 377/1500
# 80/80 [==============================] - 0s 501us/step - loss: -0.0596
# Epoch 378/1500
# 80/80 [==============================] - 0s 526us/step - loss: 0.0133
# Epoch 379/1500
# 80/80 [==============================] - 0s 607us/step - loss: -0.0562
# Epoch 380/1500
# 80/80 [==============================] - 0s 522us/step - loss: -0.0582
# Epoch 381/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0643
# Epoch 382/1500
# 80/80 [==============================] - 0s 502us/step - loss: -0.0421
# Epoch 383/1500
# 80/80 [==============================] - 0s 526us/step - loss: -0.0240
# Epoch 384/1500
# 80/80 [==============================] - 0s 504us/step - loss: 0.0037
# Epoch 385/1500
# 80/80 [==============================] - 0s 661us/step - loss: -0.0498
# Epoch 386/1500
# 80/80 [==============================] - 0s 522us/step - loss: -0.0500
# Epoch 387/1500
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0125
# Epoch 388/1500
# 80/80 [==============================] - 0s 507us/step - loss: -0.0598
# Epoch 389/1500
# 80/80 [==============================] - 0s 624us/step - loss: -0.0248
# Epoch 390/1500
# 80/80 [==============================] - 0s 489us/step - loss: -0.0219
# Epoch 391/1500
# 80/80 [==============================] - 0s 530us/step - loss: -0.0440
# Epoch 392/1500
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0182
# Epoch 393/1500
# 80/80 [==============================] - 0s 560us/step - loss: -0.0537
# Epoch 394/1500
# 80/80 [==============================] - 0s 516us/step - loss: -0.0698
# Epoch 395/1500
# 80/80 [==============================] - 0s 504us/step - loss: -0.0698
# Epoch 396/1500
# 80/80 [==============================] - 0s 503us/step - loss: -0.0452
# Epoch 397/1500
# 80/80 [==============================] - 0s 518us/step - loss: 0.0206
# Epoch 398/1500
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0407
# Epoch 399/1500
# 80/80 [==============================] - 0s 505us/step - loss: -0.0433
# Epoch 400/1500
# 80/80 [==============================] - 0s 512us/step - loss: -0.0414
# Epoch 401/1500
# 80/80 [==============================] - 0s 530us/step - loss: 0.0379
# Epoch 402/1500
# 80/80 [==============================] - 0s 579us/step - loss: -0.0671
# Epoch 403/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0407
# Epoch 404/1500
# 80/80 [==============================] - 0s 488us/step - loss: -0.0714
# Epoch 405/1500
# 80/80 [==============================] - 0s 537us/step - loss: -0.0172
# Epoch 406/1500
# 80/80 [==============================] - 0s 595us/step - loss: -0.0419
# Epoch 407/1500
# 80/80 [==============================] - 0s 508us/step - loss: -0.0488
# Epoch 408/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0655
# Epoch 409/1500
# 80/80 [==============================] - 0s 653us/step - loss: -0.0230
# Epoch 410/1500
# 80/80 [==============================] - 0s 572us/step - loss: -0.0101
# Epoch 411/1500
# 80/80 [==============================] - 0s 525us/step - loss: -0.0182
# Epoch 412/1500
# 80/80 [==============================] - 0s 498us/step - loss: -0.0088
# Epoch 413/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0534
# Epoch 414/1500
# 80/80 [==============================] - 0s 512us/step - loss: -0.0213
# Epoch 415/1500
# 80/80 [==============================] - 0s 512us/step - loss: -0.0262
# Epoch 416/1500
# 80/80 [==============================] - 0s 508us/step - loss: -0.0232
# Epoch 417/1500
# 80/80 [==============================] - 0s 516us/step - loss: -0.0079
# Epoch 418/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0378
# Epoch 419/1500
# 80/80 [==============================] - 0s 512us/step - loss: -0.0104
# Epoch 420/1500
# 80/80 [==============================] - 0s 508us/step - loss: -0.0363
# Epoch 421/1500
# 80/80 [==============================] - 0s 618us/step - loss: -0.0566
# Epoch 422/1500
# 80/80 [==============================] - 0s 522us/step - loss: -0.0609
# Epoch 423/1500
# 80/80 [==============================] - 0s 520us/step - loss: 0.0128
# Epoch 424/1500
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0109
# Epoch 425/1500
# 80/80 [==============================] - 0s 523us/step - loss: -0.0335
# Epoch 426/1500
# 80/80 [==============================] - 0s 535us/step - loss: -0.0443
# Epoch 427/1500
# 80/80 [==============================] - 0s 546us/step - loss: -0.0805
# Epoch 428/1500
# 80/80 [==============================] - 0s 520us/step - loss: -0.0590
# Epoch 429/1500
# 80/80 [==============================] - 0s 702us/step - loss: -0.0401
# Epoch 430/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0052
# Epoch 431/1500
# 80/80 [==============================] - 0s 545us/step - loss: 0.0111
# Epoch 432/1500
# 80/80 [==============================] - 0s 711us/step - loss: -0.0415
# Epoch 433/1500
# 80/80 [==============================] - 0s 531us/step - loss: -0.0563
# Epoch 434/1500
# 80/80 [==============================] - 0s 542us/step - loss: -0.0161
# Epoch 435/1500
# 80/80 [==============================] - 0s 2ms/step - loss: -0.0183
# Epoch 436/1500
# 80/80 [==============================] - 0s 574us/step - loss: -0.0420
# Epoch 437/1500
# 80/80 [==============================] - 0s 510us/step - loss: -0.0661
# Epoch 438/1500
# 80/80 [==============================] - 0s 510us/step - loss: -0.0449
# Epoch 439/1500
# 80/80 [==============================] - 0s 595us/step - loss: 0.0478
# Epoch 440/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0219
# Epoch 441/1500
# 80/80 [==============================] - 0s 524us/step - loss: 0.0240
# Epoch 442/1500
# 80/80 [==============================] - 0s 509us/step - loss: 0.0551
# Epoch 443/1500
# 80/80 [==============================] - 0s 513us/step - loss: -0.0660
# Epoch 444/1500
# 80/80 [==============================] - 0s 608us/step - loss: -0.0307
# Epoch 445/1500
# 80/80 [==============================] - 0s 534us/step - loss: -0.0375
# Epoch 446/1500
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0055
# Epoch 447/1500
# 80/80 [==============================] - 0s 512us/step - loss: -0.0395
# Epoch 448/1500
# 80/80 [==============================] - 0s 507us/step - loss: -0.0045
# Epoch 449/1500
# 80/80 [==============================] - 0s 611us/step - loss: -0.0675
# Epoch 450/1500
# 80/80 [==============================] - 0s 513us/step - loss: -0.0178
# Epoch 451/1500
# 80/80 [==============================] - 0s 516us/step - loss: -0.0237
# Epoch 452/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0089
# Epoch 453/1500
# 80/80 [==============================] - 0s 527us/step - loss: -0.0364
# Epoch 454/1500
# 80/80 [==============================] - 0s 521us/step - loss: -0.0242
# Epoch 455/1500
# 80/80 [==============================] - 0s 513us/step - loss: -0.0442
# Epoch 456/1500
# 80/80 [==============================] - 0s 601us/step - loss: -0.0522
# Epoch 457/1500
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0145
# Epoch 458/1500
# 80/80 [==============================] - 0s 530us/step - loss: -0.0285
# Epoch 459/1500
# 80/80 [==============================] - 0s 509us/step - loss: -0.0637
# Epoch 460/1500
# 80/80 [==============================] - 0s 512us/step - loss: -0.0241
# Epoch 461/1500
# 80/80 [==============================] - 0s 666us/step - loss: -0.0552
# Epoch 462/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0385
# Epoch 463/1500
# 80/80 [==============================] - 0s 518us/step - loss: -0.0517
# Epoch 464/1500
# 80/80 [==============================] - 0s 636us/step - loss: -0.0256
# Epoch 465/1500
# 80/80 [==============================] - 0s 513us/step - loss: -0.0677
# Epoch 466/1500
# 80/80 [==============================] - 0s 520us/step - loss: 0.0023
# Epoch 467/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0376
# Epoch 468/1500
# 80/80 [==============================] - 0s 532us/step - loss: -0.0134
# Epoch 469/1500
# 80/80 [==============================] - 0s 514us/step - loss: -0.0098
# Epoch 470/1500
# 80/80 [==============================] - 0s 504us/step - loss: 0.0242
# Epoch 471/1500
# 80/80 [==============================] - 0s 524us/step - loss: -0.0415
# Epoch 472/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0544
# Epoch 473/1500
# 80/80 [==============================] - 0s 515us/step - loss: -0.0537
# Epoch 474/1500
# 80/80 [==============================] - 0s 527us/step - loss: -0.0540
# Epoch 475/1500
# 80/80 [==============================] - 0s 560us/step - loss: 0.0523
# Epoch 476/1500
# 80/80 [==============================] - 0s 534us/step - loss: -0.0085
# Epoch 477/1500
# 80/80 [==============================] - 0s 506us/step - loss: -0.0426
# Epoch 478/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0644
# Epoch 479/1500
# 80/80 [==============================] - 0s 503us/step - loss: -0.0154
# Epoch 480/1500
# 80/80 [==============================] - 0s 630us/step - loss: -0.0624
# Epoch 481/1500
# 80/80 [==============================] - 0s 530us/step - loss: -0.0216
# Epoch 482/1500
# 80/80 [==============================] - 0s 518us/step - loss: -0.0219
# Epoch 483/1500
# 80/80 [==============================] - 0s 514us/step - loss: -0.0303
# Epoch 484/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0357
# Epoch 485/1500
# 80/80 [==============================] - 0s 516us/step - loss: -0.0602
# Epoch 486/1500
# 80/80 [==============================] - 0s 545us/step - loss: -0.0492
# Epoch 487/1500
# 80/80 [==============================] - 0s 574us/step - loss: -0.0132
# Epoch 488/1500
# 80/80 [==============================] - 0s 519us/step - loss: -0.0580
# Epoch 489/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0631
# Epoch 490/1500
# 80/80 [==============================] - 0s 519us/step - loss: 0.0085
# Epoch 491/1500
# 80/80 [==============================] - 0s 645us/step - loss: -0.0207
# Epoch 492/1500
# 80/80 [==============================] - 0s 518us/step - loss: -0.0503
# Epoch 493/1500
# 80/80 [==============================] - 0s 501us/step - loss: -0.0283
# Epoch 494/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0783
# Epoch 495/1500
# 80/80 [==============================] - 0s 500us/step - loss: 0.0034
# Epoch 496/1500
# 80/80 [==============================] - 0s 504us/step - loss: 0.0169
# Epoch 497/1500
# 80/80 [==============================] - 0s 501us/step - loss: 0.0279
# Epoch 498/1500
# 80/80 [==============================] - 0s 588us/step - loss: -0.0264
# Epoch 499/1500
# 80/80 [==============================] - 0s 544us/step - loss: -0.0288
# Epoch 500/1500
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0145
# Epoch 501/1500
# 80/80 [==============================] - 0s 502us/step - loss: 0.0254
# Epoch 502/1500
# 80/80 [==============================] - 0s 602us/step - loss: -0.0236
# Epoch 503/1500
# 80/80 [==============================] - 0s 535us/step - loss: -0.0796
# Epoch 504/1500
# 80/80 [==============================] - 0s 524us/step - loss: -0.0565
# Epoch 505/1500
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0652
# Epoch 506/1500
# 80/80 [==============================] - 0s 632us/step - loss: -0.0707
# Epoch 507/1500
# 80/80 [==============================] - 0s 532us/step - loss: -0.0574
# Epoch 508/1500
# 80/80 [==============================] - 0s 518us/step - loss: -0.0093
# Epoch 509/1500
# 80/80 [==============================] - 0s 513us/step - loss: -0.0410
# Epoch 510/1500
# 80/80 [==============================] - 0s 590us/step - loss: -0.0651
# Epoch 511/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0522
# Epoch 512/1500
# 80/80 [==============================] - 0s 575us/step - loss: -0.0446
# Epoch 513/1500
# 80/80 [==============================] - 0s 506us/step - loss: -0.0023
# Epoch 514/1500
# 80/80 [==============================] - 0s 514us/step - loss: -0.0501
# Epoch 515/1500
# 80/80 [==============================] - 0s 624us/step - loss: -0.0109
# Epoch 516/1500
# 80/80 [==============================] - 0s 559us/step - loss: -0.0199
# Epoch 517/1500
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0417
# Epoch 518/1500
# 80/80 [==============================] - 0s 513us/step - loss: -0.0566
# Epoch 519/1500
# 80/80 [==============================] - 0s 623us/step - loss: -0.0477
# Epoch 520/1500
# 80/80 [==============================] - 0s 530us/step - loss: -0.0486
# Epoch 521/1500
# 80/80 [==============================] - 0s 496us/step - loss: 0.0251
# Epoch 522/1500
# 80/80 [==============================] - 0s 519us/step - loss: -0.0305
# Epoch 523/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0248
# Epoch 524/1500
# 80/80 [==============================] - 0s 539us/step - loss: -0.0350
# Epoch 525/1500
# 80/80 [==============================] - 0s 501us/step - loss: -0.0260
# Epoch 526/1500
# 80/80 [==============================] - 0s 531us/step - loss: -0.0257
# Epoch 527/1500
# 80/80 [==============================] - 0s 628us/step - loss: -6.6439e-04
# Epoch 528/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0247
# Epoch 529/1500
# 80/80 [==============================] - 0s 680us/step - loss: -0.0376
# Epoch 530/1500
# 80/80 [==============================] - 0s 615us/step - loss: -0.0541
# Epoch 531/1500
# 80/80 [==============================] - 0s 532us/step - loss: -0.0362
# Epoch 532/1500
# 80/80 [==============================] - 0s 499us/step - loss: 0.0155
# Epoch 533/1500
# 80/80 [==============================] - 0s 512us/step - loss: 0.0133
# Epoch 534/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0399
# Epoch 535/1500
# 80/80 [==============================] - 0s 529us/step - loss: 0.0131
# Epoch 536/1500
# 80/80 [==============================] - 0s 500us/step - loss: -0.0585
# Epoch 537/1500
# 80/80 [==============================] - 0s 516us/step - loss: -0.0703
# Epoch 538/1500
# 80/80 [==============================] - 0s 644us/step - loss: -0.0526
# Epoch 539/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0670
# Epoch 540/1500
# 80/80 [==============================] - 0s 550us/step - loss: -7.3119e-04
# Epoch 541/1500
# 80/80 [==============================] - 0s 618us/step - loss: -0.0677
# Epoch 542/1500
# 80/80 [==============================] - 0s 519us/step - loss: 8.2680e-04
# Epoch 543/1500
# 80/80 [==============================] - 0s 523us/step - loss: -0.0691
# Epoch 544/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0660
# Epoch 545/1500
# 80/80 [==============================] - 0s 616us/step - loss: -0.0342
# Epoch 546/1500
# 80/80 [==============================] - 0s 517us/step - loss: -0.0357
# Epoch 547/1500
# 80/80 [==============================] - 0s 505us/step - loss: -0.0464
# Epoch 548/1500
# 80/80 [==============================] - 0s 593us/step - loss: 0.0842
# Epoch 549/1500
# 80/80 [==============================] - 0s 564us/step - loss: -0.0364
# Epoch 550/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0524
# Epoch 551/1500
# 80/80 [==============================] - 0s 523us/step - loss: -0.0256
# Epoch 552/1500
# 80/80 [==============================] - 0s 571us/step - loss: -0.0556
# Epoch 553/1500
# 80/80 [==============================] - 0s 538us/step - loss: -0.0579
# Epoch 554/1500
# 80/80 [==============================] - 0s 529us/step - loss: -0.0687
# Epoch 555/1500
# 80/80 [==============================] - 0s 506us/step - loss: 0.0014
# Epoch 556/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0577
# Epoch 557/1500
# 80/80 [==============================] - 0s 567us/step - loss: -0.0284
# Epoch 558/1500
# 80/80 [==============================] - 0s 530us/step - loss: -0.0019
# Epoch 559/1500
# 80/80 [==============================] - 0s 521us/step - loss: -0.0588
# Epoch 560/1500
# 80/80 [==============================] - 0s 625us/step - loss: -0.0468
# Epoch 561/1500
# 80/80 [==============================] - 0s 554us/step - loss: -0.0133
# Epoch 562/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0438
# Epoch 563/1500
# ...
# Epoch 1317/1500
# 80/80 [==============================] - 0s 475us/step - loss: -0.0649
# Epoch 1318/1500
# 80/80 [==============================] - 0s 517us/step - loss: -0.0338
# Epoch 1319/1500
# 80/80 [==============================] - 0s 578us/step - loss: -0.0551
# Epoch 1320/1500
# 80/80 [==============================] - 0s 526us/step - loss: -0.0569
# Epoch 1321/1500
# 80/80 [==============================] - 0s 474us/step - loss: 0.1147
# Epoch 1322/1500
# 80/80 [==============================] - 0s 522us/step - loss: -0.0585
# Epoch 1323/1500
# 80/80 [==============================] - 0s 493us/step - loss: -0.0499
# Epoch 1324/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0333
# Epoch 1325/1500
# 80/80 [==============================] - 0s 463us/step - loss: -0.0174
# Epoch 1326/1500
# 80/80 [==============================] - 0s 463us/step - loss: -0.0449
# Epoch 1327/1500
# 80/80 [==============================] - 0s 614us/step - loss: -0.0044
# Epoch 1328/1500
# 80/80 [==============================] - 0s 463us/step - loss: -0.0564
# Epoch 1329/1500
# 80/80 [==============================] - 0s 479us/step - loss: -0.0032
# Epoch 1330/1500
# 80/80 [==============================] - 0s 482us/step - loss: -0.0037
# Epoch 1331/1500
# 80/80 [==============================] - 0s 489us/step - loss: -0.0082
# Epoch 1332/1500
# 80/80 [==============================] - 0s 620us/step - loss: -0.0067
# Epoch 1333/1500
# 80/80 [==============================] - 0s 496us/step - loss: -0.0706
# Epoch 1334/1500
# 80/80 [==============================] - 0s 479us/step - loss: -0.0617
# Epoch 1335/1500
# 80/80 [==============================] - 0s 485us/step - loss: -0.0060
# Epoch 1336/1500
# 80/80 [==============================] - 0s 489us/step - loss: -0.0295
# Epoch 1337/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0469
# Epoch 1338/1500
# 80/80 [==============================] - 0s 466us/step - loss: -0.0161
# Epoch 1339/1500
# 80/80 [==============================] - 0s 477us/step - loss: -0.0290
# Epoch 1340/1500
# 80/80 [==============================] - 0s 487us/step - loss: -0.0277
# Epoch 1341/1500
# 80/80 [==============================] - 0s 615us/step - loss: -0.0455
# Epoch 1342/1500
# 80/80 [==============================] - 0s 518us/step - loss: -0.0332
# Epoch 1343/1500
# 80/80 [==============================] - 0s 483us/step - loss: -0.0017
# Epoch 1344/1500
# 80/80 [==============================] - 0s 497us/step - loss: -0.0518
# Epoch 1345/1500
# 80/80 [==============================] - 0s 587us/step - loss: -0.0286
# Epoch 1346/1500
# 80/80 [==============================] - 0s 472us/step - loss: -0.0516
# Epoch 1347/1500
# 80/80 [==============================] - 0s 485us/step - loss: -0.0691
# Epoch 1348/1500
# 80/80 [==============================] - 0s 472us/step - loss: -0.0479
# Epoch 1349/1500
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0113
# Epoch 1350/1500
# 80/80 [==============================] - 0s 481us/step - loss: -0.0056
# Epoch 1351/1500
# 80/80 [==============================] - 0s 470us/step - loss: 0.0038
# Epoch 1352/1500
# 80/80 [==============================] - 0s 487us/step - loss: -0.0470
# Epoch 1353/1500
# 80/80 [==============================] - 0s 615us/step - loss: -0.0351
# Epoch 1354/1500
# 80/80 [==============================] - 0s 478us/step - loss: -0.0515
# Epoch 1355/1500
# 80/80 [==============================] - 0s 482us/step - loss: -0.0423
# Epoch 1356/1500
# 80/80 [==============================] - 0s 475us/step - loss: -0.0593
# Epoch 1357/1500
# 80/80 [==============================] - 0s 610us/step - loss: -0.0226
# Epoch 1358/1500
# 80/80 [==============================] - 0s 479us/step - loss: 0.0295
# Epoch 1359/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0432
# Epoch 1360/1500
# 80/80 [==============================] - 0s 487us/step - loss: -0.0454
# Epoch 1361/1500
# 80/80 [==============================] - 0s 591us/step - loss: -0.0186
# Epoch 1362/1500
# 80/80 [==============================] - 0s 485us/step - loss: -0.0250
# Epoch 1363/1500
# 80/80 [==============================] - 0s 476us/step - loss: -0.0470
# Epoch 1364/1500
# 80/80 [==============================] - 0s 478us/step - loss: -0.0669
# Epoch 1365/1500
# 80/80 [==============================] - 0s 503us/step - loss: -0.0460
# Epoch 1366/1500
# 80/80 [==============================] - 0s 470us/step - loss: -0.0621
# Epoch 1367/1500
# 80/80 [==============================] - 0s 655us/step - loss: 0.0501
# Epoch 1368/1500
# 80/80 [==============================] - 0s 744us/step - loss: -0.0097
# Epoch 1369/1500
# 80/80 [==============================] - 0s 910us/step - loss: 0.0580
# Epoch 1370/1500
# 80/80 [==============================] - 0s 552us/step - loss: -0.0506
# Epoch 1371/1500
# 80/80 [==============================] - 0s 487us/step - loss: -0.0216
# Epoch 1372/1500
# 80/80 [==============================] - 0s 473us/step - loss: -0.0599
# Epoch 1373/1500
# 80/80 [==============================] - 0s 489us/step - loss: -0.0422
# Epoch 1374/1500
# 80/80 [==============================] - 0s 466us/step - loss: -0.0599
# Epoch 1375/1500
# 80/80 [==============================] - 0s 555us/step - loss: -0.0438
# Epoch 1376/1500
# 80/80 [==============================] - 0s 550us/step - loss: -0.0073
# Epoch 1377/1500
# 80/80 [==============================] - 0s 487us/step - loss: 0.0214
# Epoch 1378/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0172
# Epoch 1379/1500
# 80/80 [==============================] - 0s 592us/step - loss: -0.0466
# Epoch 1380/1500
# 80/80 [==============================] - 0s 488us/step - loss: -0.0345
# Epoch 1381/1500
# 80/80 [==============================] - 0s 463us/step - loss: -0.0565
# Epoch 1382/1500
# 80/80 [==============================] - 0s 479us/step - loss: -0.0701
# Epoch 1383/1500
# 80/80 [==============================] - 0s 484us/step - loss: -0.0368
# Epoch 1384/1500
# 80/80 [==============================] - 0s 620us/step - loss: -0.0140
# Epoch 1385/1500
# 80/80 [==============================] - 0s 496us/step - loss: 0.0157
# Epoch 1386/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0029
# Epoch 1387/1500
# 80/80 [==============================] - 0s 545us/step - loss: -0.0320
# Epoch 1388/1500
# 80/80 [==============================] - 0s 645us/step - loss: 0.0103
# Epoch 1389/1500
# 80/80 [==============================] - 0s 474us/step - loss: -0.0360
# Epoch 1390/1500
# 80/80 [==============================] - 0s 468us/step - loss: -0.0605
# Epoch 1391/1500
# 80/80 [==============================] - 0s 477us/step - loss: -0.0684
# Epoch 1392/1500
# 80/80 [==============================] - 0s 482us/step - loss: -0.0561
# Epoch 1393/1500
# 80/80 [==============================] - 0s 623us/step - loss: -0.0348
# Epoch 1394/1500
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0114
# Epoch 1395/1500
# 80/80 [==============================] - 0s 618us/step - loss: -0.0654
# Epoch 1396/1500
# 80/80 [==============================] - 0s 523us/step - loss: -0.0410
# Epoch 1397/1500
# 80/80 [==============================] - 0s 518us/step - loss: -0.0313
# Epoch 1398/1500
# 80/80 [==============================] - 0s 484us/step - loss: -0.0390
# Epoch 1399/1500
# 80/80 [==============================] - 0s 464us/step - loss: 0.0356
# Epoch 1400/1500
# 80/80 [==============================] - 0s 469us/step - loss: -0.0481
# Epoch 1401/1500
# 80/80 [==============================] - 0s 574us/step - loss: -0.0551
# Epoch 1402/1500
# 80/80 [==============================] - 0s 514us/step - loss: -0.0291
# Epoch 1403/1500
# 80/80 [==============================] - 0s 481us/step - loss: -0.0436
# Epoch 1404/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0510
# Epoch 1405/1500
# 80/80 [==============================] - 0s 617us/step - loss: -0.0375
# Epoch 1406/1500
# 80/80 [==============================] - 0s 465us/step - loss: -0.0552
# Epoch 1407/1500
# 80/80 [==============================] - 0s 473us/step - loss: 0.0253
# Epoch 1408/1500
# 80/80 [==============================] - 0s 459us/step - loss: -0.0412
# Epoch 1409/1500
# 80/80 [==============================] - 0s 479us/step - loss: -0.0465
# Epoch 1410/1500
# 80/80 [==============================] - 0s 573us/step - loss: -0.0361
# Epoch 1411/1500
# 80/80 [==============================] - 0s 515us/step - loss: -0.0277
# Epoch 1412/1500
# 80/80 [==============================] - 0s 479us/step - loss: -0.0559
# Epoch 1413/1500
# 80/80 [==============================] - 0s 467us/step - loss: -0.0349
# Epoch 1414/1500
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0192
# Epoch 1415/1500
# 80/80 [==============================] - 0s 522us/step - loss: -0.0448
# Epoch 1416/1500
# 80/80 [==============================] - 0s 485us/step - loss: -0.0314
# Epoch 1417/1500
# 80/80 [==============================] - 0s 457us/step - loss: -0.0330
# Epoch 1418/1500
# 80/80 [==============================] - 0s 513us/step - loss: -0.0150
# Epoch 1419/1500
# 80/80 [==============================] - 0s 568us/step - loss: -0.0381
# Epoch 1420/1500
# 80/80 [==============================] - 0s 478us/step - loss: 0.0262
# Epoch 1421/1500
# 80/80 [==============================] - 0s 491us/step - loss: 0.0053
# Epoch 1422/1500
# 80/80 [==============================] - 0s 467us/step - loss: -0.0590
# Epoch 1423/1500
# 80/80 [==============================] - 0s 461us/step - loss: -0.0465
# Epoch 1424/1500
# 80/80 [==============================] - 0s 2ms/step - loss: -0.0190
# Epoch 1425/1500
# 80/80 [==============================] - 0s 655us/step - loss: -0.0022
# Epoch 1426/1500
# 80/80 [==============================] - 0s 490us/step - loss: -0.0533
# Epoch 1427/1500
# 80/80 [==============================] - 0s 550us/step - loss: 0.0268
# Epoch 1428/1500
# 80/80 [==============================] - 0s 516us/step - loss: -0.0369
# Epoch 1429/1500
# 80/80 [==============================] - 0s 472us/step - loss: -0.0586
# Epoch 1430/1500
# 80/80 [==============================] - 0s 483us/step - loss: -0.0181
# Epoch 1431/1500
# 80/80 [==============================] - 0s 505us/step - loss: -0.0507
# Epoch 1432/1500
# 80/80 [==============================] - 0s 487us/step - loss: -0.0197
# Epoch 1433/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0485
# Epoch 1434/1500
# 80/80 [==============================] - 0s 494us/step - loss: -0.0111
# Epoch 1435/1500
# 80/80 [==============================] - 0s 485us/step - loss: -0.0120
# Epoch 1436/1500
# 80/80 [==============================] - 0s 478us/step - loss: -0.0594
# Epoch 1437/1500
# 80/80 [==============================] - 0s 577us/step - loss: -0.0619
# Epoch 1438/1500
# 80/80 [==============================] - 0s 522us/step - loss: 0.0018
# Epoch 1439/1500
# 80/80 [==============================] - 0s 477us/step - loss: -0.0567
# Epoch 1440/1500
# 80/80 [==============================] - 0s 478us/step - loss: -0.0625
# Epoch 1441/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0200
# Epoch 1442/1500
# 80/80 [==============================] - 0s 524us/step - loss: -0.0659
# Epoch 1443/1500
# 80/80 [==============================] - 0s 485us/step - loss: 0.0380
# Epoch 1444/1500
# 80/80 [==============================] - 0s 473us/step - loss: -0.0129
# Epoch 1445/1500
# 80/80 [==============================] - 0s 470us/step - loss: -0.0156
# Epoch 1446/1500
# 80/80 [==============================] - 0s 553us/step - loss: 0.0028
# Epoch 1447/1500
# 80/80 [==============================] - 0s 563us/step - loss: -0.0421
# Epoch 1448/1500
# 80/80 [==============================] - 0s 461us/step - loss: -0.0192
# Epoch 1449/1500
# 80/80 [==============================] - 0s 470us/step - loss: -0.0723
# Epoch 1450/1500
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 1451/1500
# 80/80 [==============================] - 0s 615us/step - loss: -0.0642
# Epoch 1452/1500
# 80/80 [==============================] - 0s 481us/step - loss: -0.0369
# Epoch 1453/1500
# 80/80 [==============================] - 0s 473us/step - loss: 0.0639
# Epoch 1454/1500
# 80/80 [==============================] - 0s 478us/step - loss: -0.0274
# Epoch 1455/1500
# 80/80 [==============================] - 0s 472us/step - loss: -0.0400
# Epoch 1456/1500
# 80/80 [==============================] - 0s 507us/step - loss: -0.0155
# Epoch 1457/1500
# 80/80 [==============================] - 0s 562us/step - loss: -0.0510
# Epoch 1458/1500
# 80/80 [==============================] - 0s 498us/step - loss: -0.0331
# Epoch 1459/1500
# 80/80 [==============================] - 0s 473us/step - loss: -0.0214
# Epoch 1460/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0303
# Epoch 1461/1500
# 80/80 [==============================] - 0s 512us/step - loss: -0.0647
# Epoch 1462/1500
# 80/80 [==============================] - 0s 472us/step - loss: -0.0240
# Epoch 1463/1500
# 80/80 [==============================] - 0s 471us/step - loss: -0.0528
# Epoch 1464/1500
# 80/80 [==============================] - 0s 477us/step - loss: 0.0023
# Epoch 1465/1500
# 80/80 [==============================] - 0s 635us/step - loss: -0.0515
# Epoch 1466/1500
# 80/80 [==============================] - 0s 477us/step - loss: 0.0027
# Epoch 1467/1500
# 80/80 [==============================] - 0s 480us/step - loss: -0.0682
# Epoch 1468/1500
# 80/80 [==============================] - 0s 481us/step - loss: -0.0482
# Epoch 1469/1500
# 80/80 [==============================] - 0s 465us/step - loss: 0.0188
# Epoch 1470/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0679
# Epoch 1471/1500
# 80/80 [==============================] - 0s 595us/step - loss: -0.0389
# Epoch 1472/1500
# 80/80 [==============================] - 0s 460us/step - loss: 0.0251
# Epoch 1473/1500
# 80/80 [==============================] - 0s 461us/step - loss: -0.0639
# Epoch 1474/1500
# 80/80 [==============================] - 0s 462us/step - loss: -0.0518
# Epoch 1475/1500
# 80/80 [==============================] - 0s 595us/step - loss: -0.0545
# Epoch 1476/1500
# 80/80 [==============================] - 0s 492us/step - loss: -0.0064
# Epoch 1477/1500
# 80/80 [==============================] - 0s 468us/step - loss: -0.0587
# Epoch 1478/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0144
# Epoch 1479/1500
# 80/80 [==============================] - 0s 540us/step - loss: -0.0396
# Epoch 1480/1500
# 80/80 [==============================] - 0s 464us/step - loss: 0.0393
# Epoch 1481/1500
# 80/80 [==============================] - 0s 475us/step - loss: 0.0021
# Epoch 1482/1500
# 80/80 [==============================] - 0s 492us/step - loss: -0.0417
# Epoch 1483/1500
# 80/80 [==============================] - 0s 468us/step - loss: -0.0676
# Epoch 1484/1500
# 80/80 [==============================] - 0s 612us/step - loss: -0.0386
# Epoch 1485/1500
# 80/80 [==============================] - 0s 487us/step - loss: 0.0033
# Epoch 1486/1500
# 80/80 [==============================] - 0s 470us/step - loss: -0.0706
# Epoch 1487/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0371
# Epoch 1488/1500
# 80/80 [==============================] - 0s 535us/step - loss: -0.0358
# Epoch 1489/1500
# 80/80 [==============================] - 0s 475us/step - loss: 0.0219
# Epoch 1490/1500
# 80/80 [==============================] - 0s 470us/step - loss: -0.0028
# Epoch 1491/1500
# 80/80 [==============================] - 0s 481us/step - loss: -0.0247
# Epoch 1492/1500
# 80/80 [==============================] - 0s 632us/step - loss: -0.0516
# Epoch 1493/1500
# 80/80 [==============================] - 0s 470us/step - loss: -0.0501
# Epoch 1494/1500
# 80/80 [==============================] - 0s 463us/step - loss: 0.0129
# Epoch 1495/1500
# 80/80 [==============================] - 0s 482us/step - loss: -0.0395
# Epoch 1496/1500
# 80/80 [==============================] - 0s 1ms/step - loss: -0.0587
# Epoch 1497/1500
# 80/80 [==============================] - 0s 479us/step - loss: -0.0752
# Epoch 1498/1500
# 80/80 [==============================] - 0s 447us/step - loss: -0.0190
# Epoch 1499/1500
# 80/80 [==============================] - 0s 477us/step - loss: -0.0494
# Epoch 1500/1500
# 80/80 [==============================] - 0s 484us/step - loss: 0.1020

# %%
# Profit.
yhat = model(val_input)
# [print(np.squeeze(w.numpy())) for w in model.weights];
assert isinstance(yhat, tfd.Distribution)

# %%
yhats = [model(val_input) for _ in range(100)]
for i, yhat in enumerate(yhats):
  m = np.squeeze(yhat.mean())
  s = np.squeeze(yhat.stddev())

# %%
val_dates = np.array(df.iloc[sequence_length+train_size:,0]).T.reshape(-1,1)
print(val_dates.shape,y2.shape,m.shape)
upper_bound = m + s
lower_bound = m - s

plt.figure(figsize=(10, 6))
plt.plot(val_dates,y2, label='True Values', color='black')
plt.plot(val_dates,m, label='Predicted Mean', color='red')
plt.fill_between(val_dates.reshape(-1), lower_bound, upper_bound, color='orange', alpha=0.3, label='Uncertainty Interval')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.title(f'{name} Predictions with Uncertainties')
plt.legend()
plt.grid(True)
plt.tight_layout()
# plt.xlim((val_dates[50][0],val_dates[350][0]))
plt.show()
# Out:
# (839, 1) (839, 1) (839,)

# %%
test_size = -80
test_input = np.lib.stride_tricks.sliding_window_view(df.iloc[test_size:-1,1].values, sequence_length)
y3 = np.array(df.iloc[sequence_length+test_size:,1]).T.astype(np.float32).reshape(-1,1)
y3shift = np.roll(y3, shift=1)
y3shift[0] = np.nan
test_dates = np.array(df.iloc[sequence_length+test_size:,0]).T.reshape(-1,1)

yhats_test = [model(test_input) for _ in range(100)]

for i, yhat in enumerate(yhats_test):
  m_test = np.squeeze(yhat.mean())
  s_test = np.squeeze(yhat.stddev())

print(test_input.shape,y3.shape,test_dates.shape,m_test.shape)
upper_bound = m_test + s_test
lower_bound = m_test - s_test

plt.figure(figsize=(10,5))
plt.plot(test_dates, y3, label='True Values', color='black',marker='o',markersize=3)
plt.plot(test_dates, y3shift, label='Shift Values', color='grey')
plt.plot(test_dates, m_test, label='Predicted Mean', color='red',marker='x',markersize=3)
plt.fill_between(test_dates.reshape(-1), lower_bound, upper_bound, color='orange', alpha=0.3, label='Uncertainty Interval')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.title(f'{name} Predictions with Uncertainties')
plt.legend(loc='best')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# (70, 10) (70, 1) (70, 1) (70,)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

def calculate_mape(true_data, forecast_data):
    absolute_percentage_errors = np.abs((true_data - forecast_data) / true_data)
    mape = np.mean(absolute_percentage_errors) * 100
    return mape

def calculate_rmse(true_data, forecast_data):
    rmse = np.sqrt(mean_squared_error(true_data, forecast_data))
    return rmse

def calculate_mae(true_data, forecast_data):
    mae = mean_absolute_error(true_data, forecast_data)
    return mae

def calculate_r2(true_data, forecast_data):
    r2 = r2_score(true_data, forecast_data)
    return r2

def calculate_forecast_bias(true_data, forecast_data):
    forecast_bias = np.mean(forecast_data - true_data)
    return forecast_bias


mape = calculate_mape(y3, m_test)
rmse = calculate_rmse(y3, m_test)
mae = calculate_mae(y3, m_test)
fb = calculate_forecast_bias(y3, m_test)
r2 = calculate_r2(y3, m_test)
print("MAPE:", mape,'\nRMSE:',rmse,'\nMAE:',mae,'\nFB:',fb,'\nR2:',r2)
print()
mape = calculate_mape(y3, np.nan_to_num(y3shift,nan=0.0))
rmse = calculate_rmse(y3, np.nan_to_num(y3shift,nan=0.0))
mae = calculate_mae(y3, np.nan_to_num(y3shift,nan=0.0))
fb = calculate_forecast_bias(y3, np.nan_to_num(y3shift,nan=0.0))
r2 = calculate_r2(y3, np.nan_to_num(y3shift,nan=0.0))
print("MAPE:", mape,'\nRMSE:',rmse,'\nMAE:',mae,'\nFB:',fb,'\nR2:',r2)
# Out:
# MAPE: 20.4697385430336
# RMSE: 13.631191
# MAE: 8.266649
# FB: -4.1243033
# R2: 0.9521793172699139
#
# MAPE: 4.180248454213142
# RMSE: 38.797657
# MAE: 13.190742
# FB: -7.8337035
# R2: 0.6126003909515362

# %%
y2 = y2.reshape(-1)
print(y2.shape,m.shape)
print(m.shape)
true_pct_changes = (np.diff(y2) / y2[:-1]) * 100
pred_pct_changes = ((m - y2) / y2) * 100 
pred_pct_changes2 = (np.diff(m) / m[:-1]) * 100

# y3 = y3.reshape(-1)
# true_pct_changes = (np.diff(y3) / y3[:-1]) * 100
# pred_pct_changes = ((m_test - y3) / y3) * 100 


print(true_pct_changes.shape)
print(pred_pct_changes.shape)
plt.figure()
plt.scatter(true_pct_changes, pred_pct_changes[:-1],color='orange',alpha=.4,label='Pred - Prev. Truth')
plt.scatter(true_pct_changes, pred_pct_changes2,color='indigo',alpha=.4,label='Pred - Prev. Pred')
plt.plot(true_pct_changes, true_pct_changes,lw=4,color='cadetblue')
plt.axhline(y=0,ls='--',color='red')
plt.axvline(x=0,ls='--',color='red')
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.legend()
plt.show()
# Out:
# (839,) (839,)
# (839,)
# (838,)
# (839,)

# %%
plt.figure(figsize=(6, 4.5))
plt.hist2d(true_pct_changes, pred_pct_changes[:-1], bins=25, cmap='jet',cmin=1)#,range=[[-2, 2], [-2, 2]]
# plt.hist2d(true_pct_changes, pred_pct_changes2, bins=25, cmap='jet',range=[[-2, 2], [-2, 2]],cmin=1)
plt.colorbar(label='Counts')
plt.xlabel('True values')
plt.ylabel('Predictions')
plt.title('2D Histogram')
plt.axhline(y=0, color='red', linestyle='-',lw=2.5)   # Horizontal line at y=0
plt.axvline(x=0, color='red', linestyle='-',lw=2.5)  # Vertical line at x=0
plt.plot(true_pct_changes, true_pct_changes, color='blue')   
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
conf_matrix = confusion_matrix(np.sign(true_pct_changes), np.sign(pred_pct_changes[:-1]), labels=[1, -1])
# conf_matrix = confusion_matrix(np.sign(true_pct_changes), np.sign(pred_pct_changes2), labels=[1, -1])
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[189 261]
#  [175 212]]

# %%
same_sign_indices = np.where(np.sign(true_pct_changes) == np.sign(pred_pct_changes[:-1]))
diff_sign_indices = np.where(np.sign(true_pct_changes) != np.sign(pred_pct_changes[:-1]))

plt.figure(figsize=(6,4))
_, bins, _ = plt.hist(true_pct_changes,bins=50,histtype='step',label='Actual Daily Returns')
plt.hist(true_pct_changes[same_sign_indices],bins=bins,histtype='step',color='green',label='Correct')
plt.hist(true_pct_changes[diff_sign_indices],bins=bins,histtype='step',color='red',label='Incorrect')
plt.grid(color='0.95')
plt.xlabel('Returns [%]')
plt.title('Test set')
x_min, x_max = plt.xlim()
y_min, y_max = plt.ylim()
text_x = x_min + 0.025 * (x_max - x_min)
text_y = y_max - 0.1 * (y_max - y_min)
plt.text(text_x, text_y, '% correct sign {:.3f}\n% incorrect sign {:.3f}'.format(len(true_pct_changes[same_sign_indices])/len(true_pct_changes),
                                                                                 len(true_pct_changes[diff_sign_indices])/len(true_pct_changes)), ha='left', va='top')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()
im = ax.imshow(conf_matrix, interpolation='nearest', cmap=plt.cm.cool)

cbar = ax.figure.colorbar(im, ax=ax)
cbar.ax.set_ylabel('Counts', rotation=-90, va="bottom")
ax.set(xlabel='Predicted labels',ylabel='True Labels')
ax.set_xticks([0,1])
ax.set_xticklabels(['1', '-1'])
ax.set_yticks([0,1])
ax.set_yticklabels(['1', '-1'])
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(j, i, str(conf_matrix[i, j]), ha="center", va="center", color="white" if conf_matrix[i, j] > conf_matrix.max() / 2 else "black")

plt.show()

# %%
#one day test
one_day_input = np.lib.stride_tricks.sliding_window_view(df.iloc[-12:,1].values, sequence_length)[:-1]
y4 = np.array(df.iloc[sequence_length-12:,1]).astype(np.float32)


print(one_day_input)
print(y4)
# Out:
# [[429.97000122 426.52999878 426.92001343 438.07998657 430.45001221
#   430.25       422.08999634 406.32000732 418.76000977 411.17001343]
#  [426.52999878 426.92001343 438.07998657 430.45001221 430.25
#   422.08999634 406.32000732 418.76000977 411.17001343 408.22000122]]
# [408.22 423.02]

# %%
#aleatoric uncertainty +- sigma
#epistemic uncertainty 100 predict calls
yhats_test = [model(one_day_input) for _ in range(100)]

means = []
stds = []
avgm = np.zeros_like(one_day_input[...,0])
for i, yhat in enumerate(yhats_test):
  means.append(yhat.mean())
  stds.append(yhat.stddev())
  m_test = np.squeeze(yhat.mean())
  s_test = np.squeeze(yhat.stddev())
  avgm += m_test/len(yhats_test)

mean_array = np.mean(np.array(means),axis=0)
std_array = np.mean(np.array(stds),axis=0)
print(mean_array)
print(std_array)
print(avgm)
# print(means)
print('Pred: ',m_test,'+-',s_test)
upper_bound = m_test + s_test
lower_bound = m_test - s_test
# print(m_test, '+-', s_test)
print('Truth: ',y4)
# Out:
# [[410.37476]
#  [406.42825]]
# [[11.973639]
#  [11.85845 ]]
# [410.37487555 406.42825651]
# Pred:  [410.5219  406.57385] +- [11.921695 11.807029]
# Truth:  [408.22 423.02]

# %%
plt.figure(figsize=(5,4))
plt.hist(s,bins=50)
plt.xlabel('Model Uncertainty $\sigma$')
plt.title('Test Set')
plt.grid(color='0.95')
plt.show()

# %%
true_pct_changes = (np.diff(y2) / y2[:-1]) * 100
pred_pct_changes = (((m - y2) / y2) * 100 )[:-1]
pred_pct_changes2 = (np.diff(m) / m[:-1]) * 100
print(pred_pct_changes.shape,pred_pct_changes2.shape,true_pct_changes.shape)

sig_cut = 4
true_pct_changes_sig = true_pct_changes[s[:-1]<sig_cut]
pred_pct_changes_sig = pred_pct_changes[s[:-1]<sig_cut]
pred_pct_changes2_sig = pred_pct_changes2[s[:-1]<sig_cut]
print(pred_pct_changes_sig.shape,pred_pct_changes2_sig.shape,true_pct_changes_sig.shape)
plt.figure()
plt.scatter(true_pct_changes_sig, pred_pct_changes_sig,color='orange',alpha=.4,label='Pred - Prev. Truth')
# plt.scatter(true_pct_changes_sig, pred_pct_changes2_sig,color='indigo',alpha=.4,label='Pred - Prev. Pred')
plt.plot(true_pct_changes_sig, true_pct_changes_sig,lw=4,color='cadetblue')
plt.axhline(y=0,ls='--',color='red')
plt.axvline(x=0,ls='--',color='red')
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.legend()
plt.show()

print(true_pct_changes[:10])
print(pred_pct_changes[:10])
same_sign_indices = np.where(np.sign(true_pct_changes_sig) == np.sign(pred_pct_changes_sig))
diff_sign_indices = np.where(np.sign(true_pct_changes_sig) != np.sign(pred_pct_changes_sig))

plt.figure(figsize=(6,4))
_, bins, _ = plt.hist(true_pct_changes_sig,bins=50,histtype='step',label='Actual Daily Returns')
plt.hist(true_pct_changes[same_sign_indices],bins=bins,histtype='step',color='green',label='Correct')
plt.hist(true_pct_changes[diff_sign_indices],bins=bins,histtype='step',color='red',label='Incorrect')
plt.grid(color='0.95')
plt.xlabel('Returns [%]')
plt.title(f'Test set (Post Cut) {sig_cut}')
x_min, x_max = plt.xlim()
y_min, y_max = plt.ylim()
text_x = x_min + 0.025 * (x_max - x_min)
text_y = y_max - 0.1 * (y_max - y_min)
plt.text(text_x, text_y, '% correct sign {:.3f}\n% incorrect sign {:.3f}'.format(len(true_pct_changes_sig[same_sign_indices])/len(true_pct_changes_sig),
                                                                                 len(true_pct_changes_sig[diff_sign_indices])/len(true_pct_changes_sig)), ha='left', va='top')
plt.legend()
plt.show()
# Out:
# (838,) (838,) (838,)
# (261,) (261,) (261,)
# [  7.002894   -3.9436226  -2.6528594  -7.7431984   6.372223   -5.5959806
#  -12.236785   11.340206  -18.452085   10.626279 ]
# [ 4.1698055 -6.2374663  3.9849396  2.969843   7.8905916 -5.744454
#   4.800993  13.913602  -9.898439  21.349945 ]
