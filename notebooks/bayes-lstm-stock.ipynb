# %%
import numpy as np
import pandas as pd
import datetime
from matplotlib import pyplot as plt
import yfinance as yf

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import tensorflow as tf
import tensorflow_probability as tfp

# %%
name = 'AAPL'

train_end_date = '2023-07-01'

name_ohlc_df = yf.download(name, start='2010-01-01', end=train_end_date)
name_ohlc_df = name_ohlc_df.reset_index()

data = {'date': name_ohlc_df.Date, 'close': name_ohlc_df.Close, 'volume': name_ohlc_df.Volume}
df = pd.DataFrame(data)
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#         date     close     volume
# 0 2010-01-04  7.643214  493729600
# 1 2010-01-05  7.656429  601904800
# 2 2010-01-06  7.534643  552160000
# 3 2010-01-07  7.520714  477131200
# 4 2010-01-08  7.570714  447610800

# %%
plt.figure(figsize=(8, 4))
plt.plot(df['date'], df['close'], linestyle='-', color='b')
plt.xlabel('Date')
plt.ylabel('Temperature')
plt.title(name+' Price')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# # x1 = np.array(df.iloc[:,1]+np.random.randn(df.shape[0])).astype(np.float32).reshape(-1,1)
# train_size = int(0.75 * len(df))

# # x1 = np.array(df.iloc[:train_size,1]).astype(np.float32).reshape(-1,1)
# sequence_length = 10
# train_input = np.lib.stride_tricks.sliding_window_view(df.iloc[:train_size,1:].values, window_shape=(sequence_length, 2)).squeeze()
# val_input = np.lib.stride_tricks.sliding_window_view(df.iloc[train_size:-1,1:].values, window_shape=(sequence_length, 2)).squeeze()

# y1 = np.array(df.iloc[sequence_length:train_size+1,1]).T.astype(np.float32).reshape(-1,1)
# y2 = np.array(df.iloc[sequence_length+train_size:,1]).T.astype(np.float32).reshape(-1,1)

# tfd = tfp.distributions

# %%
train_size = int(0.75 * len(df))

# x1 = np.array(df.iloc[:train_size,1]).astype(np.float32).reshape(-1,1)
sequence_length = 10
train_input = np.lib.stride_tricks.sliding_window_view(df.iloc[:train_size,1].values, sequence_length)
val_input = np.lib.stride_tricks.sliding_window_view(df.iloc[train_size:-1,1].values, sequence_length)

y1 = np.array(df.iloc[sequence_length:train_size+1,1]).T.astype(np.float32).reshape(-1,1)
y2 = np.array(df.iloc[sequence_length+train_size:,1]).T.astype(np.float32).reshape(-1,1)

tfd = tfp.distributions

# %%
# print(train_input[:2])
# print()
# print(y1[:2])
# print(train_input.shape,y1.shape)
print(val_input[:2])
print()
print(y2[:2])
print(val_input.shape,y2.shape)
# Out:
# [[79.75       80.90499878 80.07499695 78.26249695 74.54499817 72.01999664
#   73.16249847 68.37999725 68.33999634 74.70249939]
#  [80.90499878 80.07499695 78.26249695 74.54499817 72.01999664 73.16249847
#   68.37999725 68.33999634 74.70249939 72.33000183]]
#
# [[72.33 ]
#  [75.685]]
# (839, 10) (839, 1)

# %%
# # Specify the surrogate posterior over `keras.layers.Dense` `kernel` and `bias`.
# def posterior_mean_field(kernel_size, bias_size=0, dtype=None):
#   n = kernel_size + bias_size
#   c = np.log(np.expm1(1.))
#   return tf.keras.Sequential([
#       tfp.layers.VariableLayer(2 * n, dtype=dtype),
#       tfp.layers.DistributionLambda(lambda t: tfd.Independent(
#           tfd.Normal(loc=t[..., :n],
#                      scale=1e-5 + tf.nn.softplus(c + t[..., n:])),
#           reinterpreted_batch_ndims=1)),
#   ])

# # Specify the prior over `keras.layers.Dense` `kernel` and `bias`.
# def prior_trainable(kernel_size, bias_size=0, dtype=None):
#   n = kernel_size + bias_size
#   return tf.keras.Sequential([
#       tfp.layers.VariableLayer(n, dtype=dtype),
#       tfp.layers.DistributionLambda(lambda t: tfd.Independent(
#           tfd.Normal(loc=t, scale=1),
#           reinterpreted_batch_ndims=1)),
#   ])

# %%
deep_model = tf.keras.Sequential([
  tf.keras.layers.LSTM(32,activation='relu',input_shape=(10,1)),
  tf.keras.layers.Dense(64,activation='relu'),
  tf.keras.layers.Dense(24,activation='relu'),
  tf.keras.layers.Dense(8,activation='relu'),
  tf.keras.layers.Dense(1+1),
  tfp.layers.DistributionLambda(
      lambda t: tfd.Normal(loc=t[..., :1],scale=1e-3 + tf.math.softplus(0.1 * t[...,1:]))),
])

# %%
# def build_lstm_model_with_distribution(input_shape):
#     inputs = tf.keras.layers.Input(shape=input_shape)
#     # lstm_output1 = tf.keras.layers.LSTM(128, return_sequences=True)(inputs)
#     # lstm_output2 = tf.keras.layers.LSTM(128, return_sequences=True)(dropout_output1)
#     # dropout_output2 = tf.keras.layers.Dropout(0.3)(lstm_output2)
#     # lstm_output3 = tf.keras.layers.LSTM(128, return_sequences=False)(inputs)
#     flatten_inputs = tf.keras.layers.Flatten()(inputs)

#     full_connect1 = tf.keras.layers.Dense(32, activation='relu')(flatten_inputs)
#     flat_mean_output = tf.keras.layers.Dense(2, activation='relu')(full_connect1)

#     # Create a distribution layer using TensorFlow Probability
#     distribution_layer =   tfp.layers.DistributionLambda(
#       lambda t: tfd.Normal(loc=t[..., :1],scale=1e-3 + tf.math.softplus(0.001 * t[...,1:]))
#       )
    
#     distribution_output = distribution_layer(flat_mean_output)
#     model = tf.keras.models.Model(inputs=inputs, outputs=distribution_output)
    
#     return model

# %%
# deep_model = build_lstm_model_with_distribution(input_shape=(sequence_length,2))

negloglik = lambda y, rv_y: -rv_y.log_prob(y)
deep_model.compile(optimizer=tf.keras.optimizers.legacy.Adam(), loss=negloglik)

# %%
deep_model.fit(train_input, y1, epochs=750, verbose=1)
# Out:
# Epoch 1/750
# 80/80 [==============================] - 1s 2ms/step - loss: 118.5791
# Epoch 2/750
# 80/80 [==============================] - 0s 2ms/step - loss: 2.3174
# Epoch 3/750
# 80/80 [==============================] - 0s 2ms/step - loss: 2.2417
# Epoch 4/750
# 80/80 [==============================] - 0s 2ms/step - loss: 2.1313
# Epoch 5/750
# 80/80 [==============================] - 0s 2ms/step - loss: 1.4729
# Epoch 6/750
# 80/80 [==============================] - 0s 2ms/step - loss: 1.1405
# Epoch 7/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.9830
# Epoch 8/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.9628
# Epoch 9/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.9768
# Epoch 10/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.8874
# Epoch 11/750
# 80/80 [==============================] - 0s 2ms/step - loss: 1.0167
# Epoch 12/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.8813
# Epoch 13/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.9090
# Epoch 14/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.8498
# Epoch 15/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.8254
# Epoch 16/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.8790
# Epoch 17/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.8567
# Epoch 18/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.8200
# Epoch 19/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.7762
# Epoch 20/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.7211
# Epoch 21/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.7815
# Epoch 22/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.8043
# Epoch 23/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.7483
# Epoch 24/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.7906
# Epoch 25/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.8718
# Epoch 26/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6962
# Epoch 27/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.7949
# Epoch 28/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.7308
# Epoch 29/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.7169
# Epoch 30/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.7236
# Epoch 31/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6927
# Epoch 32/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.7348
# Epoch 33/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6827
# Epoch 34/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.7368
# Epoch 35/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.7411
# Epoch 36/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.7112
# Epoch 37/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.7117
# Epoch 38/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.7080
# Epoch 39/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.7612
# Epoch 40/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6889
# Epoch 41/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6630
# Epoch 42/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6211
# Epoch 43/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.7380
# Epoch 44/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.8091
# Epoch 45/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6608
# Epoch 46/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6727
# Epoch 47/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6276
# Epoch 48/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6817
# Epoch 49/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6120
# Epoch 50/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6315
# Epoch 51/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6120
# Epoch 52/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6951
# Epoch 53/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6113
# Epoch 54/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6609
# Epoch 55/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6933
# Epoch 56/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.7002
# Epoch 57/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6158
# Epoch 58/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6134
# Epoch 59/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6570
# Epoch 60/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5886
# Epoch 61/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.7002
# Epoch 62/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6626
# Epoch 63/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6944
# Epoch 64/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6835
# Epoch 65/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6441
# Epoch 66/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6596
# Epoch 67/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6723
# Epoch 68/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6091
# Epoch 69/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6111
# Epoch 70/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5809
# Epoch 71/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.7065
# Epoch 72/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5752
# Epoch 73/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6279
# Epoch 74/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6023
# Epoch 75/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5923
# Epoch 76/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5769
# Epoch 77/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5783
# Epoch 78/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6922
# Epoch 79/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6142
# Epoch 80/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5900
# Epoch 81/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6517
# Epoch 82/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6092
# Epoch 83/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.7047
# Epoch 84/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6005
# Epoch 85/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6341
# Epoch 86/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.7025
# Epoch 87/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.7026
# Epoch 88/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6058
# Epoch 89/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6595
# Epoch 90/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6122
# Epoch 91/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5756
# Epoch 92/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6315
# Epoch 93/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5612
# Epoch 94/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6361
# Epoch 95/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6492
# Epoch 96/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5849
# Epoch 97/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5980
# Epoch 98/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5879
# Epoch 99/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5822
# Epoch 100/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6322
# Epoch 101/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5815
# Epoch 102/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6354
# Epoch 103/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5742
# Epoch 104/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5933
# Epoch 105/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6395
# Epoch 106/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6491
# Epoch 107/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6161
# Epoch 108/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5749
# Epoch 109/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5678
# Epoch 110/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5952
# Epoch 111/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5699
# Epoch 112/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6270
# Epoch 113/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6203
# Epoch 114/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5873
# Epoch 115/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6451
# Epoch 116/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6024
# Epoch 117/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6206
# Epoch 118/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6514
# Epoch 119/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6296
# Epoch 120/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6130
# Epoch 121/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5906
# Epoch 122/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5693
# Epoch 123/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6102
# Epoch 124/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5711
# Epoch 125/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5832
# Epoch 126/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5848
# Epoch 127/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5484
# Epoch 128/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6771
# Epoch 129/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5523
# Epoch 130/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5528
# Epoch 131/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5766
# Epoch 132/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6297
# Epoch 133/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5621
# Epoch 134/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6161
# Epoch 135/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5638
# Epoch 136/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5922
# Epoch 137/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5710
# Epoch 138/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5395
# Epoch 139/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6515
# Epoch 140/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5943
# Epoch 141/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6248
# Epoch 142/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6788
# Epoch 143/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5410
# Epoch 144/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5700
# Epoch 145/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5471
# Epoch 146/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5859
# Epoch 147/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5533
# Epoch 148/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5446
# Epoch 149/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6218
# Epoch 150/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5814
# Epoch 151/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5597
# Epoch 152/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5493
# Epoch 153/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5823
# Epoch 154/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5993
# Epoch 155/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6269
# Epoch 156/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5913
# Epoch 157/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5691
# Epoch 158/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5539
# Epoch 159/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5446
# Epoch 160/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5527
# Epoch 161/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5719
# Epoch 162/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5355
# Epoch 163/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5888
# Epoch 164/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5313
# Epoch 165/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5850
# Epoch 166/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5560
# Epoch 167/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5611
# Epoch 168/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5754
# Epoch 169/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5672
# Epoch 170/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5821
# Epoch 171/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6564
# Epoch 172/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5914
# Epoch 173/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5960
# Epoch 174/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5300
# Epoch 175/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5670
# Epoch 176/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5653
# Epoch 177/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5350
# Epoch 178/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5659
# Epoch 179/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6350
# Epoch 180/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6026
# Epoch 181/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5561
# Epoch 182/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5601
# Epoch 183/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5491
# Epoch 184/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5886
# Epoch 185/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5981
# Epoch 186/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6476
# Epoch 187/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5443
# Epoch 188/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5770
# Epoch 189/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5811
# Epoch 190/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5842
# Epoch 191/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5650
# Epoch 192/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5363
# Epoch 193/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5243
# Epoch 194/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5492
# Epoch 195/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5880
# Epoch 196/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5959
# Epoch 197/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6060
# Epoch 198/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5653
# Epoch 199/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5314
# Epoch 200/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5485
# Epoch 201/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5867
# Epoch 202/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5544
# Epoch 203/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5267
# Epoch 204/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5758
# Epoch 205/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6716
# Epoch 206/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6130
# Epoch 207/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5727
# Epoch 208/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5662
# Epoch 209/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5562
# Epoch 210/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5474
# Epoch 211/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6168
# Epoch 212/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5351
# Epoch 213/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5246
# Epoch 214/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6016
# Epoch 215/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5691
# Epoch 216/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5774
# Epoch 217/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6250
# Epoch 218/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6505
# Epoch 219/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5810
# Epoch 220/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5653
# Epoch 221/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5333
# Epoch 222/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5859
# Epoch 223/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5486
# Epoch 224/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5989
# Epoch 225/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5838
# Epoch 226/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5184
# Epoch 227/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5682
# Epoch 228/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5086
# Epoch 229/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5730
# Epoch 230/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5762
# Epoch 231/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5806
# Epoch 232/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6954
# Epoch 233/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5768
# Epoch 234/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5466
# Epoch 235/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5708
# Epoch 236/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5446
# Epoch 237/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5484
# Epoch 238/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5624
# Epoch 239/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5175
# Epoch 240/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5451
# Epoch 241/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5709
# Epoch 242/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5777
# Epoch 243/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5870
# Epoch 244/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5839
# Epoch 245/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5644
# Epoch 246/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5395
# Epoch 247/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5380
# Epoch 248/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5809
# Epoch 249/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5472
# Epoch 250/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5248
# Epoch 251/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5930
# Epoch 252/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5720
# Epoch 253/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5331
# Epoch 254/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5855
# Epoch 255/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5637
# Epoch 256/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5635
# Epoch 257/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5116
# Epoch 258/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5836
# Epoch 259/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5711
# Epoch 260/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5436
# Epoch 261/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5716
# Epoch 262/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5488
# Epoch 263/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5683
# Epoch 264/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5502
# Epoch 265/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5700
# Epoch 266/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5251
# Epoch 267/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6206
# Epoch 268/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5456
# Epoch 269/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6132
# Epoch 270/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5476
# Epoch 271/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5519
# Epoch 272/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5169
# Epoch 273/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5530
# Epoch 274/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5765
# Epoch 275/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5609
# Epoch 276/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5691
# Epoch 277/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5273
# Epoch 278/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5386
# Epoch 279/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5740
# Epoch 280/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5443
# Epoch 281/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5714
# Epoch 282/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5712
# Epoch 283/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5725
# Epoch 284/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5385
# Epoch 285/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5698
# Epoch 286/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5575
# Epoch 287/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5542
# Epoch 288/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5710
# Epoch 289/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5065
# Epoch 290/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5756
# Epoch 291/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5566
# Epoch 292/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5565
# Epoch 293/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5554
# Epoch 294/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5617
# Epoch 295/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5490
# Epoch 296/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5250
# Epoch 297/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5491
# Epoch 298/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5292
# Epoch 299/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5364
# Epoch 300/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5408
# Epoch 301/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5095
# Epoch 302/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6006
# Epoch 303/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5402
# Epoch 304/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5628
# Epoch 305/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6179
# Epoch 306/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5291
# Epoch 307/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5527
# Epoch 308/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5277
# Epoch 309/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5287
# Epoch 310/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5310
# Epoch 311/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5199
# Epoch 312/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5550
# Epoch 313/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5475
# Epoch 314/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5256
# Epoch 315/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5591
# Epoch 316/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5778
# Epoch 317/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5266
# Epoch 318/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5339
# Epoch 319/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5432
# Epoch 320/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5902
# Epoch 321/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5279
# Epoch 322/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5430
# Epoch 323/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5379
# Epoch 324/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6032
# Epoch 325/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5421
# Epoch 326/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5555
# Epoch 327/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5591
# Epoch 328/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5220
# Epoch 329/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5266
# Epoch 330/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5609
# Epoch 331/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5550
# Epoch 332/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5473
# Epoch 333/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5156
# Epoch 334/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5682
# Epoch 335/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5236
# Epoch 336/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5288
# Epoch 337/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5299
# Epoch 338/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5269
# Epoch 339/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5322
# Epoch 340/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5277
# Epoch 341/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5475
# Epoch 342/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5500
# Epoch 343/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5350
# Epoch 344/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5405
# Epoch 345/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5144
# Epoch 346/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5221
# Epoch 347/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5509
# Epoch 348/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5580
# Epoch 349/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5380
# Epoch 350/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5689
# Epoch 351/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5780
# Epoch 352/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5154
# Epoch 353/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5070
# Epoch 354/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5370
# Epoch 355/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5906
# Epoch 356/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6161
# Epoch 357/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5431
# Epoch 358/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5223
# Epoch 359/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5632
# Epoch 360/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5396
# Epoch 361/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5477
# Epoch 362/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5388
# Epoch 363/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5410
# Epoch 364/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5162
# Epoch 365/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5334
# Epoch 366/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5400
# Epoch 367/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5338
# Epoch 368/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5558
# Epoch 369/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5323
# Epoch 370/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5395
# Epoch 371/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5311
# Epoch 372/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5597
# Epoch 373/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5366
# Epoch 374/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5159
# Epoch 375/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5766
# Epoch 376/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5430
# Epoch 377/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5786
# Epoch 378/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5220
# Epoch 379/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5185
# Epoch 380/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5222
# Epoch 381/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5594
# Epoch 382/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5444
# Epoch 383/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5565
# Epoch 384/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5834
# Epoch 385/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5441
# Epoch 386/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5453
# Epoch 387/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5324
# Epoch 388/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5845
# Epoch 389/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5118
# Epoch 390/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5319
# Epoch 391/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5602
# Epoch 392/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5439
# Epoch 393/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5185
# Epoch 394/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5642
# Epoch 395/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5241
# Epoch 396/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5476
# Epoch 397/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5249
# Epoch 398/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5315
# Epoch 399/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5450
# Epoch 400/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5449
# Epoch 401/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5183
# Epoch 402/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6036
# Epoch 403/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5988
# Epoch 404/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5179
# Epoch 405/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5762
# Epoch 406/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5222
# Epoch 407/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5530
# Epoch 408/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6073
# Epoch 409/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5376
# Epoch 410/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5083
# Epoch 411/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5391
# Epoch 412/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5338
# Epoch 413/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5555
# Epoch 414/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5378
# Epoch 415/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5474
# Epoch 416/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5152
# Epoch 417/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5750
# Epoch 418/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5310
# Epoch 419/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5261
# Epoch 420/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5817
# Epoch 421/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5691
# Epoch 422/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5410
# Epoch 423/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5293
# Epoch 424/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5388
# Epoch 425/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5507
# Epoch 426/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5440
# Epoch 427/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5753
# Epoch 428/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5514
# Epoch 429/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5978
# Epoch 430/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5988
# Epoch 431/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5784
# Epoch 432/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5342
# Epoch 433/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5327
# Epoch 434/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5058
# Epoch 435/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5315
# Epoch 436/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5126
# Epoch 437/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5347
# Epoch 438/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5193
# Epoch 439/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5493
# Epoch 440/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5732
# Epoch 441/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5423
# Epoch 442/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5663
# Epoch 443/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5359
# Epoch 444/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5407
# Epoch 445/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5482
# Epoch 446/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5672
# Epoch 447/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5748
# Epoch 448/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5585
# Epoch 449/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5280
# Epoch 450/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5225
# Epoch 451/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5531
# Epoch 452/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5500
# Epoch 453/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.4931
# Epoch 454/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5304
# Epoch 455/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5266
# Epoch 456/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5711
# Epoch 457/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5056
# Epoch 458/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5521
# Epoch 459/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5066
# Epoch 460/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5248
# Epoch 461/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5106
# Epoch 462/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5734
# Epoch 463/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5124
# Epoch 464/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5016
# Epoch 465/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5051
# Epoch 466/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5355
# Epoch 467/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5213
# Epoch 468/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5366
# Epoch 469/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5126
# Epoch 470/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5732
# Epoch 471/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.4963
# Epoch 472/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5370
# Epoch 473/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5084
# Epoch 474/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5359
# Epoch 475/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6158
# Epoch 476/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5332
# Epoch 477/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5133
# Epoch 478/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5397
# Epoch 479/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5749
# Epoch 480/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.4890
# Epoch 481/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5826
# Epoch 482/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5124
# Epoch 483/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5660
# Epoch 484/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5660
# Epoch 485/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5427
# Epoch 486/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5913
# Epoch 487/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5348
# Epoch 488/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5339
# Epoch 489/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5123
# Epoch 490/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5425
# Epoch 491/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5201
# Epoch 492/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5290
# Epoch 493/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5760
# Epoch 494/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5072
# Epoch 495/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5072
# Epoch 496/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5236
# Epoch 497/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5259
# Epoch 498/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5040
# Epoch 499/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5254
# Epoch 500/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5283
# Epoch 501/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5296
# Epoch 502/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5150
# Epoch 503/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5663
# Epoch 504/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5112
# Epoch 505/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5431
# Epoch 506/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5671
# Epoch 507/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5733
# Epoch 508/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5500
# Epoch 509/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5329
# Epoch 510/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5363
# Epoch 511/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5195
# Epoch 512/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6316
# Epoch 513/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5513
# Epoch 514/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5905
# Epoch 515/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5226
# Epoch 516/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5044
# Epoch 517/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5217
# Epoch 518/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5316
# Epoch 519/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5283
# Epoch 520/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5261
# Epoch 521/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5433
# Epoch 522/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5216
# Epoch 523/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5279
# Epoch 524/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5466
# Epoch 525/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5865
# Epoch 526/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5146
# Epoch 527/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5207
# Epoch 528/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5552
# Epoch 529/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5133
# Epoch 530/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5168
# Epoch 531/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5023
# Epoch 532/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5140
# Epoch 533/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5374
# Epoch 534/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5328
# Epoch 535/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5229
# Epoch 536/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5478
# Epoch 537/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5419
# Epoch 538/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5032
# Epoch 539/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5901
# Epoch 540/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5041
# Epoch 541/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5183
# Epoch 542/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5196
# Epoch 543/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5226
# Epoch 544/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5083
# Epoch 545/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5132
# Epoch 546/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5751
# Epoch 547/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5143
# Epoch 548/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5089
# Epoch 549/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5242
# Epoch 550/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5354
# Epoch 551/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5383
# Epoch 552/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5100
# Epoch 553/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5247
# Epoch 554/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5329
# Epoch 555/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5085
# Epoch 556/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5203
# Epoch 557/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5313
# Epoch 558/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5193
# Epoch 559/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5201
# Epoch 560/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5745
# Epoch 561/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5297
# Epoch 562/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5270
# Epoch 563/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5238
# Epoch 564/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5334
# Epoch 565/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.4922
# Epoch 566/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5306
# Epoch 567/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5220
# Epoch 568/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5278
# Epoch 569/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5268
# Epoch 570/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5431
# Epoch 571/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5186
# Epoch 572/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5470
# Epoch 573/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5463
# Epoch 574/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5488
# Epoch 575/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5174
# Epoch 576/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5178
# Epoch 577/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5095
# Epoch 578/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5081
# Epoch 579/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5189
# Epoch 580/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5190
# Epoch 581/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5093
# Epoch 582/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5147
# Epoch 583/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5484
# Epoch 584/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.4916
# Epoch 585/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5768
# Epoch 586/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5691
# Epoch 587/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5064
# Epoch 588/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5611
# Epoch 589/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5303
# Epoch 590/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5169
# Epoch 591/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5294
# Epoch 592/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5291
# Epoch 593/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5161
# Epoch 594/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.4994
# Epoch 595/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.4945
# Epoch 596/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5217
# Epoch 597/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6020
# Epoch 598/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5860
# Epoch 599/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.4942
# Epoch 600/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5103
# Epoch 601/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5389
# Epoch 602/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5454
# Epoch 603/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5109
# Epoch 604/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5149
# Epoch 605/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5178
# Epoch 606/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5322
# Epoch 607/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5275
# Epoch 608/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5374
# Epoch 609/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.4953
# Epoch 610/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5266
# Epoch 611/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5187
# Epoch 612/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5460
# Epoch 613/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5238
# Epoch 614/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5205
# Epoch 615/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5480
# Epoch 616/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5390
# Epoch 617/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5635
# Epoch 618/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.4964
# Epoch 619/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.4942
# Epoch 620/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5093
# Epoch 621/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5174
# Epoch 622/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.4968
# Epoch 623/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5478
# Epoch 624/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5348
# Epoch 625/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5934
# Epoch 626/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5588
# Epoch 627/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6441
# Epoch 628/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5447
# Epoch 629/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5002
# Epoch 630/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.4997
# Epoch 631/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5293
# Epoch 632/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5202
# Epoch 633/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5077
# Epoch 634/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5230
# Epoch 635/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5348
# Epoch 636/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5218
# Epoch 637/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5107
# Epoch 638/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5109
# Epoch 639/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5735
# Epoch 640/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5282
# Epoch 641/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5252
# Epoch 642/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5169
# Epoch 643/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5018
# Epoch 644/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5017
# Epoch 645/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5573
# Epoch 646/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.4972
# Epoch 647/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5532
# Epoch 648/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.4996
# Epoch 649/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5053
# Epoch 650/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5260
# Epoch 651/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5192
# Epoch 652/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5183
# Epoch 653/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5313
# Epoch 654/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.4980
# Epoch 655/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5257
# Epoch 656/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5481
# Epoch 657/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5817
# Epoch 658/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5173
# Epoch 659/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.4972
# Epoch 660/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5141
# Epoch 661/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5096
# Epoch 662/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5179
# Epoch 663/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5138
# Epoch 664/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5027
# Epoch 665/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5017
# Epoch 666/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.4970
# Epoch 667/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5190
# Epoch 668/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5380
# Epoch 669/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5179
# Epoch 670/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5122
# Epoch 671/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.4909
# Epoch 672/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5138
# Epoch 673/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5042
# Epoch 674/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5182
# Epoch 675/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5414
# Epoch 676/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5294
# Epoch 677/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6315
# Epoch 678/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5507
# Epoch 679/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5074
# Epoch 680/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5563
# Epoch 681/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5796
# Epoch 682/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5363
# Epoch 683/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5177
# Epoch 684/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5351
# Epoch 685/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5459
# Epoch 686/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5647
# Epoch 687/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5173
# Epoch 688/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5401
# Epoch 689/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5297
# Epoch 690/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5059
# Epoch 691/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5520
# Epoch 692/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5076
# Epoch 693/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5323
# Epoch 694/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5277
# Epoch 695/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5229
# Epoch 696/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5305
# Epoch 697/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.4890
# Epoch 698/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5333
# Epoch 699/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5264
# Epoch 700/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5326
# Epoch 701/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5322
# Epoch 702/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5057
# Epoch 703/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5300
# Epoch 704/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5026
# Epoch 705/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5059
# Epoch 706/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5195
# Epoch 707/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5175
# Epoch 708/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.4999
# Epoch 709/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5237
# Epoch 710/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5287
# Epoch 711/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5054
# Epoch 712/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5399
# Epoch 713/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5319
# Epoch 714/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5291
# Epoch 715/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.4945
# Epoch 716/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5124
# Epoch 717/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5347
# Epoch 718/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5470
# Epoch 719/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5459
# Epoch 720/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5450
# Epoch 721/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.4822
# Epoch 722/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5061
# Epoch 723/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5046
# Epoch 724/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5172
# Epoch 725/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5613
# Epoch 726/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5025
# Epoch 727/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5452
# Epoch 728/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5117
# Epoch 729/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5600
# Epoch 730/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5688
# Epoch 731/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5309
# Epoch 732/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5270
# Epoch 733/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5368
# Epoch 734/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5093
# Epoch 735/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5598
# Epoch 736/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.4957
# Epoch 737/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.4925
# Epoch 738/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5138
# Epoch 739/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5092
# Epoch 740/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.4820
# Epoch 741/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5629
# Epoch 742/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5323
# Epoch 743/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5180
# Epoch 744/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5075
# Epoch 745/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5113
# Epoch 746/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5242
# Epoch 747/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5402
# Epoch 748/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.4871
# Epoch 749/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.4917
# Epoch 750/750
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5273

# %%
# Profit.
yhat = deep_model(val_input)
# [print(np.squeeze(w.numpy())) for w in model.weights];
assert isinstance(yhat, tfd.Distribution)

# %%
yhats = [deep_model(val_input) for _ in range(100)]
for i, yhat in enumerate(yhats):
  m = np.squeeze(yhat.mean())
  s = np.squeeze(yhat.stddev())

# %%
val_dates = np.array(df.iloc[sequence_length+train_size:,0]).T.reshape(-1,1)
print(val_dates.shape,y2.shape,m.shape)
upper_bound = m + s
lower_bound = m - s

plt.figure(figsize=(10, 6))
plt.plot(val_dates,y2, label='True Values', color='black')
plt.plot(val_dates,m, label='Predicted Mean', color='red')
plt.fill_between(val_dates.reshape(-1), lower_bound, upper_bound, color='orange', alpha=0.3, label='Uncertainty Interval')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.title(f'{name} Predictions with Uncertainties')
plt.legend()
plt.grid(True)
plt.tight_layout()
# plt.xlim((val_dates[50][0],val_dates[350][0]))
plt.show()
# Out:
# (839, 1) (839, 1) (839,)

# %%
test_size = -80
test_input = np.lib.stride_tricks.sliding_window_view(df.iloc[test_size:-1,1].values, sequence_length)
y3 = np.array(df.iloc[sequence_length+test_size:,1]).T.astype(np.float32).reshape(-1,1)
y3shift = np.roll(y3, shift=1)
y3shift[0] = np.nan
test_dates = np.array(df.iloc[sequence_length+test_size:,0]).T.reshape(-1,1)

yhats_test = [deep_model(test_input) for _ in range(100)]

for i, yhat in enumerate(yhats_test):
  m_test = np.squeeze(yhat.mean())
  s_test = np.squeeze(yhat.stddev())

print(test_input.shape,y3.shape,test_dates.shape,m_test.shape)
upper_bound = m_test + s_test
lower_bound = m_test - s_test

plt.figure(figsize=(10,5))
plt.plot(test_dates, y3, label='True Values', color='black',marker='o',markersize=3)
plt.plot(test_dates, y3shift, label='Shift Values', color='grey',marker='o',ms=3)
plt.plot(test_dates, m_test, label='Predicted Mean', color='red',marker='x',markersize=3)
plt.fill_between(test_dates.reshape(-1), lower_bound, upper_bound, color='orange', alpha=0.3, label='Uncertainty Interval')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.title(f'{name} Predictions with Uncertainties')
plt.legend(loc='best')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# (70, 10) (70, 1) (70, 1) (70,)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

def calculate_mape(true_data, forecast_data):
    absolute_percentage_errors = np.abs((true_data - forecast_data) / true_data)
    mape = np.mean(absolute_percentage_errors) * 100
    return mape

def calculate_rmse(true_data, forecast_data):
    rmse = np.sqrt(mean_squared_error(true_data, forecast_data))
    return rmse

def calculate_mae(true_data, forecast_data):
    mae = mean_absolute_error(true_data, forecast_data)
    return mae

def calculate_r2(true_data, forecast_data):
    r2 = r2_score(true_data, forecast_data)
    return r2

def calculate_forecast_bias(true_data, forecast_data):
    forecast_bias = np.mean(forecast_data - true_data)
    return forecast_bias


mape = calculate_mape(y3, m_test)
rmse = calculate_rmse(y3, m_test)
mae = calculate_mae(y3, m_test)
fb = calculate_forecast_bias(y3, m_test)
r2 = calculate_r2(y3, m_test)
print("MAPE:", mape,'\nRMSE:',rmse,'\nMAE:',mae,'\nFB:',fb,'\nR2:',r2)
print()
mape = calculate_mape(y3, np.nan_to_num(y3shift,nan=0.0))
rmse = calculate_rmse(y3, np.nan_to_num(y3shift,nan=0.0))
mae = calculate_mae(y3, np.nan_to_num(y3shift,nan=0.0))
fb = calculate_forecast_bias(y3, np.nan_to_num(y3shift,nan=0.0))
r2 = calculate_r2(y3, np.nan_to_num(y3shift,nan=0.0))
print("MAPE:", mape,'\nRMSE:',rmse,'\nMAE:',mae,'\nFB:',fb,'\nR2:',r2)
# Out:
# MAPE: 6.538200378417969
# RMSE: 7.4822927
# MAE: 5.681463
# FB: -4.4824605
# R2: 0.3288908474826401
#
# MAPE: 2.266642451286316
# RMSE: 18.968864
# MAE: 3.7024279
# FB: -2.771
# R2: -3.313268018930917

# %%
#strategy
#find the days were the price today is below -2sigma or above +2sigma
print(val_dates.shape,y2.shape,m.shape,s.shape)
prediction_df = pd.DataFrame({'Date':val_dates.squeeze(),'Close':y2.squeeze(), 
                              'Model_mean':m, 'Model_sigma':s})
prediction_df['m+3s'] = prediction_df['Model_mean'] + 3*prediction_df['Model_sigma']
prediction_df['m-3s'] = prediction_df['Model_mean'] - 3*prediction_df['Model_sigma']
prediction_df.head()
print()
# Out:
# (839, 1) (839, 1) (839,) (839,)

# %%
condition1 = prediction_df['Close'] > prediction_df['m+3s']
condition2 = prediction_df['Close'] < prediction_df['m-3s']
# combined_condition = condition1 | condition2
above_result = prediction_df[condition1]
above_result_dates = above_result['Date'].tolist()
below_result = prediction_df[condition2]
below_result_dates = below_result['Date'].tolist()
print(len(above_result))
print(len(below_result))

plt.figure(figsize=(10, 6))
plt.plot(prediction_df['Date'],prediction_df['Close'], label='True Values', color='black')
plt.plot(prediction_df['Date'],prediction_df['Model_mean'], label='Predicted Mean', color='red')
plt.fill_between(prediction_df['Date'], prediction_df['m-3s'], prediction_df['m+3s'], color='indigo', alpha=0.3, label='$3\sigma$ Uncertainty')
plt.vlines(above_result_dates,ymin=0,ymax=max(prediction_df['m+3s']), color='green', linestyle='--', label='Above Cond. Met',alpha=0.5)
plt.vlines(below_result_dates,ymin=0,ymax=max(prediction_df['m+3s']), color='r', linestyle='--', label='Below Cond. Met',alpha=0.5)

plt.xlabel('Time Step')
plt.ylabel('Value')
plt.title(f'{name} Predictions with Uncertainties')
plt.legend()
plt.grid(True)
plt.tight_layout()
# plt.xlim((prediction_df[50][0],prediction_df[350][0]))
plt.show()
# Out:
# 251
# 51

# %%
y2 = y2.reshape(-1)
print(y2.shape,m.shape)
print(m.shape)
true_pct_changes = (np.diff(y2) / y2[:-1]) * 100
pred_pct_changes = ((m - y2) / y2) * 100 
pred_pct_changes2 = (np.diff(m) / m[:-1]) * 100

# y3 = y3.reshape(-1)
# true_pct_changes = (np.diff(y3) / y3[:-1]) * 100
# pred_pct_changes = ((m_test - y3) / y3) * 100 


print(true_pct_changes.shape)
print(pred_pct_changes.shape)
plt.figure()
plt.scatter(true_pct_changes, pred_pct_changes[:-1],color='orange',alpha=.4,label='Pred - Prev. Truth')
plt.scatter(true_pct_changes, pred_pct_changes2,color='indigo',alpha=.4,label='Pred - Prev. Pred')
plt.plot(true_pct_changes, true_pct_changes,lw=4,color='cadetblue')
plt.axhline(y=0,ls='--',color='red')
plt.axvline(x=0,ls='--',color='red')
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.legend()
plt.show()
# Out:
# (839,) (839,)
# (839,)
# (838,)
# (839,)

# %%
plt.figure(figsize=(6, 4.5))
plt.hist2d(true_pct_changes, pred_pct_changes[:-1], bins=25, cmap='jet',cmin=1)#,range=[[-2, 2], [-2, 2]]
# plt.hist2d(true_pct_changes, pred_pct_changes2, bins=25, cmap='jet',range=[[-2, 2], [-2, 2]],cmin=1)
plt.colorbar(label='Counts')
plt.xlabel('True values')
plt.ylabel('Predictions')
plt.title('2D Histogram')
plt.axhline(y=0, color='red', linestyle='-',lw=2.5)   # Horizontal line at y=0
plt.axvline(x=0, color='red', linestyle='-',lw=2.5)  # Vertical line at x=0
plt.plot(true_pct_changes, true_pct_changes, color='blue')   
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
conf_matrix = confusion_matrix(np.sign(true_pct_changes), np.sign(pred_pct_changes[:-1]), labels=[1, -1])
# conf_matrix = confusion_matrix(np.sign(true_pct_changes), np.sign(pred_pct_changes2), labels=[1, -1])
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[147 292]
#  [104 292]]

# %%
same_sign_indices = np.where(np.sign(true_pct_changes) == np.sign(pred_pct_changes[:-1]))
diff_sign_indices = np.where(np.sign(true_pct_changes) != np.sign(pred_pct_changes[:-1]))

plt.figure(figsize=(6,4))
_, bins, _ = plt.hist(true_pct_changes,bins=50,histtype='step',label='Actual Daily Returns')
plt.hist(true_pct_changes[same_sign_indices],bins=bins,histtype='step',color='green',label='Correct')
plt.hist(true_pct_changes[diff_sign_indices],bins=bins,histtype='step',color='red',label='Incorrect')
plt.grid(color='0.95')
plt.xlabel('Returns [%]')
plt.title('Test set')
x_min, x_max = plt.xlim()
y_min, y_max = plt.ylim()
text_x = x_min + 0.025 * (x_max - x_min)
text_y = y_max - 0.1 * (y_max - y_min)
plt.text(text_x, text_y, '% correct sign {:.3f}\n% incorrect sign {:.3f}'.format(len(true_pct_changes[same_sign_indices])/len(true_pct_changes),
                                                                                 len(true_pct_changes[diff_sign_indices])/len(true_pct_changes)), ha='left', va='top')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()
im = ax.imshow(conf_matrix, interpolation='nearest', cmap=plt.cm.cool)

cbar = ax.figure.colorbar(im, ax=ax)
cbar.ax.set_ylabel('Counts', rotation=-90, va="bottom")
ax.set(xlabel='Predicted labels',ylabel='True Labels')
ax.set_xticks([0,1])
ax.set_xticklabels(['1', '-1'])
ax.set_yticks([0,1])
ax.set_yticklabels(['1', '-1'])
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(j, i, str(conf_matrix[i, j]), ha="center", va="center", color="white" if conf_matrix[i, j] > conf_matrix.max() / 2 else "black")

plt.show()

# %%
#one day test
one_day_input = np.lib.stride_tricks.sliding_window_view(df.iloc[-12:,1].values, sequence_length)[:-1]
y4 = np.array(df.iloc[sequence_length-12:,1]).astype(np.float32)


print(one_day_input)
print(y4)
# Out:
# [[183.94999695 186.00999451 184.91999817 185.00999451 183.96000671
#   187.         186.67999268 185.27000427 188.05999756 189.25      ]
#  [186.00999451 184.91999817 185.00999451 183.96000671 187.
#   186.67999268 185.27000427 188.05999756 189.25       189.58999634]]
# [189.59 193.97]

# %%
#aleatoric uncertainty +- sigma
#epistemic uncertainty 100 predict calls
yhats_test = [model(one_day_input) for _ in range(100)]

means = []
stds = []
avgm = np.zeros_like(one_day_input[...,0])
for i, yhat in enumerate(yhats_test):
  means.append(yhat.mean())
  stds.append(yhat.stddev())
  m_test = np.squeeze(yhat.mean())
  s_test = np.squeeze(yhat.stddev())
  avgm += m_test/len(yhats_test)

mean_array = np.mean(np.array(means),axis=0)
std_array = np.mean(np.array(stds),axis=0)
print(mean_array)
print(std_array)
print(avgm)
# print(means)
print('Pred: ',m_test,'+-',s_test)
upper_bound = m_test + s_test
lower_bound = m_test - s_test
# print(m_test, '+-', s_test)
print('Truth: ',y4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/leonbozianu/work/lightbox/notebooks/bayes-lstm-stock.ipynb Cell 27 line 3
#       <a href='vscode-notebook-cell:/Users/leonbozianu/work/lightbox/notebooks/bayes-lstm-stock.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> #aleatoric uncertainty +- sigma
#       <a href='vscode-notebook-cell:/Users/leonbozianu/work/lightbox/notebooks/bayes-lstm-stock.ipynb#X35sZmlsZQ%3D%3D?line=1'>2</a> #epistemic uncertainty 100 predict calls
# ----> <a href='vscode-notebook-cell:/Users/leonbozianu/work/lightbox/notebooks/bayes-lstm-stock.ipynb#X35sZmlsZQ%3D%3D?line=2'>3</a> yhats_test = [model(one_day_input) for _ in range(100)]
#       <a href='vscode-notebook-cell:/Users/leonbozianu/work/lightbox/notebooks/bayes-lstm-stock.ipynb#X35sZmlsZQ%3D%3D?line=4'>5</a> means = []
#       <a href='vscode-notebook-cell:/Users/leonbozianu/work/lightbox/notebooks/bayes-lstm-stock.ipynb#X35sZmlsZQ%3D%3D?line=5'>6</a> stds = []
#
# /Users/leonbozianu/work/lightbox/notebooks/bayes-lstm-stock.ipynb Cell 27 line 3
#       <a href='vscode-notebook-cell:/Users/leonbozianu/work/lightbox/notebooks/bayes-lstm-stock.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> #aleatoric uncertainty +- sigma
#       <a href='vscode-notebook-cell:/Users/leonbozianu/work/lightbox/notebooks/bayes-lstm-stock.ipynb#X35sZmlsZQ%3D%3D?line=1'>2</a> #epistemic uncertainty 100 predict calls
# ----> <a href='vscode-notebook-cell:/Users/leonbozianu/work/lightbox/notebooks/bayes-lstm-stock.ipynb#X35sZmlsZQ%3D%3D?line=2'>3</a> yhats_test = [model(one_day_input) for _ in range(100)]
#       <a href='vscode-notebook-cell:/Users/leonbozianu/work/lightbox/notebooks/bayes-lstm-stock.ipynb#X35sZmlsZQ%3D%3D?line=4'>5</a> means = []
#       <a href='vscode-notebook-cell:/Users/leonbozianu/work/lightbox/notebooks/bayes-lstm-stock.ipynb#X35sZmlsZQ%3D%3D?line=5'>6</a> stds = []
#
# NameError: name 'model' is not defined

# %%
plt.figure(figsize=(5,4))
plt.hist(s,bins=50)
plt.xlabel('Model Uncertainty $\sigma$')
plt.title('Test Set')
plt.grid(color='0.95')
plt.show()

# %%
true_pct_changes = (np.diff(y2) / y2[:-1]) * 100
pred_pct_changes = (((m - y2) / y2) * 100 )[:-1]
pred_pct_changes2 = (np.diff(m) / m[:-1]) * 100
print(pred_pct_changes.shape,pred_pct_changes2.shape,true_pct_changes.shape)

sig_cut = 4
true_pct_changes_sig = true_pct_changes[s[:-1]<sig_cut]
pred_pct_changes_sig = pred_pct_changes[s[:-1]<sig_cut]
pred_pct_changes2_sig = pred_pct_changes2[s[:-1]<sig_cut]
print(pred_pct_changes_sig.shape,pred_pct_changes2_sig.shape,true_pct_changes_sig.shape)
plt.figure()
plt.scatter(true_pct_changes_sig, pred_pct_changes_sig,color='orange',alpha=.4,label='Pred - Prev. Truth')
# plt.scatter(true_pct_changes_sig, pred_pct_changes2_sig,color='indigo',alpha=.4,label='Pred - Prev. Pred')
plt.plot(true_pct_changes_sig, true_pct_changes_sig,lw=4,color='cadetblue')
plt.axhline(y=0,ls='--',color='red')
plt.axvline(x=0,ls='--',color='red')
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.legend()
plt.show()

print(true_pct_changes[:10])
print(pred_pct_changes[:10])
same_sign_indices = np.where(np.sign(true_pct_changes_sig) == np.sign(pred_pct_changes_sig))
diff_sign_indices = np.where(np.sign(true_pct_changes_sig) != np.sign(pred_pct_changes_sig))

plt.figure(figsize=(6,4))
_, bins, _ = plt.hist(true_pct_changes_sig,bins=50,histtype='step',label='Actual Daily Returns')
plt.hist(true_pct_changes[same_sign_indices],bins=bins,histtype='step',color='green',label='Correct')
plt.hist(true_pct_changes[diff_sign_indices],bins=bins,histtype='step',color='red',label='Incorrect')
plt.grid(color='0.95')
plt.xlabel('Returns [%]')
plt.title(f'Test set (Post Cut) {sig_cut}')
x_min, x_max = plt.xlim()
y_min, y_max = plt.ylim()
text_x = x_min + 0.025 * (x_max - x_min)
text_y = y_max - 0.1 * (y_max - y_min)
plt.text(text_x, text_y, '% correct sign {:.3f}\n% incorrect sign {:.3f}'.format(len(true_pct_changes_sig[same_sign_indices])/len(true_pct_changes_sig),
                                                                                 len(true_pct_changes_sig[diff_sign_indices])/len(true_pct_changes_sig)), ha='left', va='top')
plt.legend()
plt.show()
